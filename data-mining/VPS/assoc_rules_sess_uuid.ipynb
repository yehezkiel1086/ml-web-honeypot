# %%
import pandas as pd

df = pd.read_json("../../datas/vps/detected.json", lines=True)

df.head(5)
# Out:
#   method                                               path  \
# 0    GET                                                  /
# 1    GET                                                  /
# 2    GET  /stylesheets/jquery/jquery-ui-1.11.0.css?15286...
# 3    GET            /stylesheets/application.css?1528612569
# 4    GET             /stylesheets/responsive.css?1528612569
#
#                                              headers  \
# 0  {'host': 'localhost', 'user-agent': 'curl/7.68...
# 1  {'host': '202.10.35.215', 'connection': 'keep-...
# 2  {'host': '202.10.35.215', 'connection': 'keep-...
# 3  {'host': '202.10.35.215', 'connection': 'keep-...
# 4  {'host': '202.10.35.215', 'connection': 'keep-...
#
#                                    uuid  \
# 0  64644ea7-b358-4208-9b28-e5aaad5e00de
# 1  64644ea7-b358-4208-9b28-e5aaad5e00de
# 2  64644ea7-b358-4208-9b28-e5aaad5e00de
# 3  64644ea7-b358-4208-9b28-e5aaad5e00de
# 4  64644ea7-b358-4208-9b28-e5aaad5e00de
#
#                                       peer  status  \
# 0      {'ip': '172.18.0.1', 'port': 53212}     200
# 1  {'ip': '180.248.32.210', 'port': 30702}     200
# 2  {'ip': '180.248.32.210', 'port': 30702}     200
# 3  {'ip': '180.248.32.210', 'port': 30709}     200
# 4   {'ip': '180.248.32.210', 'port': 8026}     200
#
#                                              cookies  \
# 0                                {'sess_uuid': None}
# 1  {'sess_uuid': '7ee68b0c-9f55-47e5-b872-078d30b...
# 2  {'sess_uuid': 'c3f38f1d-a1be-477a-8692-9369ce7...
# 3  {'sess_uuid': 'c3f38f1d-a1be-477a-8692-9369ce7...
# 4  {'sess_uuid': 'c3f38f1d-a1be-477a-8692-9369ce7...
#
#                                         response_msg  \
# 0  {'version': '0.6.0', 'response': {'message': {...
# 1  {'version': '0.6.0', 'response': {'message': {...
# 2  {'version': '0.6.0', 'response': {'message': {...
# 3  {'version': '0.6.0', 'response': {'message': {...
# 4  {'version': '0.6.0', 'response': {'message': {...
#
#                    timestamp post_data
# 0 2025-06-14 07:30:36.539037       NaN
# 1 2025-06-14 07:31:01.702421       NaN
# 2 2025-06-14 07:31:01.860896       NaN
# 3 2025-06-14 07:31:02.008505       NaN
# 4 2025-06-14 07:31:02.020142       NaN

# %%
sess_uuids_matrix = []
tmp = []
sess_uuids_uuids = {
  # "{sess_uuid}": []
}
uuids = []

for _, row in df.iterrows():
  uuid = row["uuid"]
  sess_uuid = row.get("cookies", {}).get("sess_uuid") or row.get("response_msg", {}).get("response", {}).get("message", {}).get("sess_uuid")

  if uuid in uuids:
    sess_uuids_uuids[uuid].append(sess_uuid)
  else:
    sess_uuids_uuids[uuid] = [sess_uuid]
    uuids.append(uuid)

sess_uuids_matrix = list(sess_uuids_uuids.values())
# for paths in sess_uuids_uuids.values():
#   sess_uuids_matrix.append(paths)

sess_uuids_uuids
# sess_uuids_matrix
# print(len(sess_uuids_matrix), len(sess_uuids_uuids.keys()))
# Out:
# {'64644ea7-b358-4208-9b28-e5aaad5e00de': ['806c8d58-b04f-4634-b107-34877af9d1d0',
#   '7ee68b0c-9f55-47e5-b872-078d30b9116b',
#   'c3f38f1d-a1be-477a-8692-9369ce7d2c44',
#   'c3f38f1d-a1be-477a-8692-9369ce7d2c44',
#   'c3f38f1d-a1be-477a-8692-9369ce7d2c44',
#   'c3f38f1d-a1be-477a-8692-9369ce7d2c44',
#   'c3f38f1d-a1be-477a-8692-9369ce7d2c44',
#   'c3f38f1d-a1be-477a-8692-9369ce7d2c44',
#   'c3f38f1d-a1be-477a-8692-9369ce7d2c44',
#   'f278a7c1-0785-48d7-bf05-539b1f48cc0c',
#   '35356d10-0d1c-47ab-b018-36f62dd2a08f',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '1e975ea3-2f2c-4183-a4ca-7637ddbe1eec',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '7c28e45f-7aaa-42fa-b44d-0216a25150ab',
#   '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd',
#   '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd',
#   '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd',
#   '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd',
#   '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd',
#   '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd',
#   '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd',
#   '47685c7c-17cb-4303-8a1e-5e99a9e1f9bd',
#   '09e54ba6-8322-4a86-afa8-a01dc89cb59b',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '09e54ba6-8322-4a86-afa8-a01dc89cb59b',
#   '09e54ba6-8322-4a86-afa8-a01dc89cb59b',
#   '09e54ba6-8322-4a86-afa8-a01dc89cb59b',
#   '09e54ba6-8322-4a86-afa8-a01dc89cb59b',
#   '09e54ba6-8322-4a86-afa8-a01dc89cb59b',
#   '09e54ba6-8322-4a86-afa8-a01dc89cb59b',
#   '09e54ba6-8322-4a86-afa8-a01dc89cb59b',
#   'fd70efc6-4bea-4488-9b48-259dedb17253',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '98ea628e-45bf-4a62-a0ee-3fab57dbf91d',
#   '832ea6af-7ac1-4971-b205-2028efaef538',
#   'a32ff6ba-c480-4519-b91e-539517820571',
#   '5a39f903-3016-4ecc-990e-e20e8813115d',
#   'f98db070-b1c2-4f1e-b019-c13361eeef96'],
#  '648c8c37-3275-4dac-9b6a-a44f4796d492': ['8de81429-7607-4d4f-b31c-5e03ff10e2bd',
#   '997a2bbc-7e8a-4088-9fb5-05809cdcaf81',
#   'f7358105-0eb0-474a-ba3e-6266aca8f90a',
#   '623bcb95-5794-42ea-86e6-b1af1a13158c',
#   'bbed53f4-35ef-4722-b8df-269a46a691f1',
#   'bbed53f4-35ef-4722-b8df-269a46a691f1',
#   'bbed53f4-35ef-4722-b8df-269a46a691f1',
#   'bbed53f4-35ef-4722-b8df-269a46a691f1',
#   '76b1da02-e6c1-4826-b881-a504aefb8f0b',
#   '3d120c94-fd09-4619-adcb-715466a1b85f',
#   '3d120c94-fd09-4619-adcb-715466a1b85f',
#   '3d120c94-fd09-4619-adcb-715466a1b85f',
#   '3d120c94-fd09-4619-adcb-715466a1b85f',
#   '3d120c94-fd09-4619-adcb-715466a1b85f',
#   '3d120c94-fd09-4619-adcb-715466a1b85f',
#   'c9f54414-6d3d-4ab0-84d9-b17a5bc56abe',
#   '67ad7734-1a0d-44c4-91fb-f5a95e0cb51f',
#   'f7358105-0eb0-474a-ba3e-6266aca8f90a',
#   '4021c006-9db4-4278-af06-808ead00ba8f',
#   '28e88c97-5ccb-4526-8113-1d65eb3aa43b',
#   '28e88c97-5ccb-4526-8113-1d65eb3aa43b',
#   'df46768d-6cf6-4b4e-bc82-7cff4ca4a9c1'],
#  '279d8e0f-3391-4a45-86f2-31ac81bab393': ['e6dc69dd-97c6-4a9d-a842-8a1802e8e0c5',
#   '252b722b-5181-4089-a148-0e6c2eedee0d',
#   '5a619609-691d-485b-ba0c-4d7ce6d9e18a',
#   'f629a009-4764-4dcf-9121-953912923945',
#   'cc4fde00-f118-490f-b158-2eab31ebdd6c',
#   '1d20892e-df9a-4816-949f-6416fa32a10a',
#   '10760847-7b34-4af7-b53e-1dc0562d21c0',
#   '356a10a8-c46b-4c4f-b990-5a87e9626ac2',
#   '5a619609-691d-485b-ba0c-4d7ce6d9e18a',
#   '9ac9975c-b405-45ff-8c33-814145f20dfd',
#   'd20be2c1-a120-4de4-94f1-474235f9c348',
#   '0c4cff42-3743-4b68-b3b7-36f3b2fb188d',
#   '0c4cff42-3743-4b68-b3b7-36f3b2fb188d',
#   '0c4cff42-3743-4b68-b3b7-36f3b2fb188d',
#   '0c4cff42-3743-4b68-b3b7-36f3b2fb188d',
#   '0c4cff42-3743-4b68-b3b7-36f3b2fb188d',
#   '0c4cff42-3743-4b68-b3b7-36f3b2fb188d',
#   '8431c9e0-a5e4-46a5-9878-90707213d930',
#   'fc3bf6c6-8482-426c-946a-4b1ba170c199',
#   '2641268e-75f3-475d-af52-c900d31271ad',
#   '8431c9e0-a5e4-46a5-9878-90707213d930'],
#  '3f7032c1-b8c2-4fd9-bcac-a79ffe525a8a': ['de6dd592-14b5-4bb6-92bb-18ff8abc824c',
#   '55769149-07b6-4749-bbaa-d0df08fc2e30',
#   '9b5a36dc-e1c3-4475-97cb-239384c081ca',
#   '11b5a22e-0363-41f7-8d3f-365b8606a054',
#   '0d785779-8cbd-4f1d-9250-e3e6d654e263',
#   '10fa9ee6-873c-4780-9a19-bfed11044f16',
#   '58152224-fefc-48dc-afa3-d793e0a8751e',
#   '1d64153a-93af-4adb-b5fa-3b2d54180c74',
#   '0765b697-19b8-458f-8c39-35c2a5dbd4e8',
#   'e5c02419-ae0a-4858-8522-1e8c9be0cb77',
#   '25634633-1fd4-4b42-b424-2e0d00a319b3',
#   'f95bef52-11a0-4551-9dbc-e9e7f2d32d01',
#   '0f8c1aba-a173-4a9e-b27f-a84e0783c1eb',
#   '62985346-cccc-45b2-8fec-37222c5d98af'],
#  'a7712161-2283-4eb0-83c6-dd498b46352d': ['9725d4c3-3552-4607-9f9c-96a4e0026d25',
#   'c83a475d-4338-442b-8001-0e0d38b31956',
#   '7c00303f-47ba-4539-beb0-8d9c990f7357',
#   'b5d26698-b551-4560-86c3-4d3ee177babd'],
#  '2007efe3-7459-4a60-8b06-2df0e77cff3e': ['4d58d4ac-5833-4b1c-acf1-6ba0d796736f',
#   '23b5c3dd-6049-42d3-87aa-a1b3df3416c9',
#   '9dea8911-285c-4993-b1d3-50257bb26d45',
#   'ec7e27a3-b079-4354-8084-e073586b77ff',
#   '1b25a153-fc12-4f38-a55e-d50f161d9bf4',
#   '516edec4-6b1e-4ec9-bdd6-c9951c0ce634',
#   'ac2d1343-f801-4411-bb53-46d18fc85e38',
#   'c7a9e64d-0d55-4e8e-abd0-2c287a3f3d83',
#   'cfe5a2ef-b02a-4d97-861f-08ba12db6f96'],
#  '52294f01-72bd-4ed1-83f0-e63f05d84af7': ['4cce0e2e-6886-4bc8-a4ef-fc8a52d9f46a',
#   'e7193848-0ace-4390-a8d0-bbf024b7272f',
#   '997a9a09-0872-4153-bb1e-72cdf4d93dd1',
#   'd31a21a3-922d-4449-ab6f-2bdcad19dbf0',
#   '133086da-e8e9-435f-ade8-6d6bf1bd067b',
#   '7fbce34f-47ac-4899-9590-fabd5936e28b',
#   '90308f2b-b69c-408c-8a0b-0190a52fad1b',
#   '2aafb35e-6e86-4cd9-aa41-a84b73cdd85e',
#   '727dae92-80c7-4381-837e-1efd67cbcc72',
#   'd31a21a3-922d-4449-ab6f-2bdcad19dbf0',
#   'c4c98f87-7499-4f78-8bc7-9eb2567e5438',
#   '5845f689-3930-4e2d-beab-c7a25d7b1690',
#   '5845f689-3930-4e2d-beab-c7a25d7b1690',
#   '5845f689-3930-4e2d-beab-c7a25d7b1690',
#   '2a00aa78-9e78-4b8e-947e-fab6883593c5',
#   '2a00aa78-9e78-4b8e-947e-fab6883593c5',
#   '2a00aa78-9e78-4b8e-947e-fab6883593c5',
#   '5845f689-3930-4e2d-beab-c7a25d7b1690'],
#  '33d8aa11-3547-4dac-bc9c-60fa108efbac': ['3111288c-8e46-4664-8ab6-869604ec77f0',
#   '2957f15c-a15a-43dc-a3c6-e617a42708c4',
#   'bb916666-895d-4787-a709-e050a0facdcb',
#   '2f176122-665e-41bd-af6c-d432e1a5acba',
#   'bf99b83d-395c-4a85-a454-2b14b34a4c7d',
#   'c85c4599-0779-4b5e-845c-139b1529c312',
#   '3105e78d-7170-41f7-a201-f0b635c56e55',
#   '754519e3-1e83-4dbf-b7d4-4775fb960226']}

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth

te = TransactionEncoder()
te_ary = te.fit(sess_uuids_matrix).transform(sess_uuids_matrix)
df = pd.DataFrame(te_ary, columns=te.columns_)

df
# Out:
#     047aa8f9-0d61-433b-8f59-f5f6f8daf6c3  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                   True
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     0765b697-19b8-458f-8c39-35c2a5dbd4e8  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                  True
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     09e54ba6-8322-4a86-afa8-a01dc89cb59b  \
# 0                                   True
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     0c4cff42-3743-4b68-b3b7-36f3b2fb188d  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                  True
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     0d785779-8cbd-4f1d-9250-e3e6d654e263  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                  True
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     0ed39147-fed9-4179-82c4-4ff84f92531f  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                   True
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     0f8c1aba-a173-4a9e-b27f-a84e0783c1eb  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                  True
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     10760847-7b34-4af7-b53e-1dc0562d21c0  \
# 0                                  False
# 1                                  False
# 2                                   True
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     10fa9ee6-873c-4780-9a19-bfed11044f16  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                  True
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     11b5a22e-0363-41f7-8d3f-365b8606a054  ...  \
# 0                                  False  ...
# 1                                  False  ...
# 2                                  False  ...
# 3                                  False  ...
# 4                                  False  ...
# 5                                  False  ...
# 6                                  False  ...
# 7                                  False  ...
# 8                                  False  ...
# 9                                  False  ...
# 10                                 False  ...
# 11                                 False  ...
# 12                                  True  ...
# 13                                 False  ...
# 14                                 False  ...
# 15                                 False  ...
# 16                                 False  ...
#
#     f278a7c1-0785-48d7-bf05-539b1f48cc0c  \
# 0                                   True
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     f629a009-4764-4dcf-9121-953912923945  \
# 0                                  False
# 1                                  False
# 2                                   True
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     f7358105-0eb0-474a-ba3e-6266aca8f90a  \
# 0                                  False
# 1                                   True
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     f8712c2e-b44e-4f46-b720-6bfceef0830b  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                   True
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     f8d5daeb-62a8-4332-9b88-3da8f0052d77  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                   True
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     f95bef52-11a0-4551-9dbc-e9e7f2d32d01  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                  True
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     f98db070-b1c2-4f1e-b019-c13361eeef96  \
# 0                                   True
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     fc3bf6c6-8482-426c-946a-4b1ba170c199  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                  True
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
#
#     fd70efc6-4bea-4488-9b48-259dedb17253  fdfea6b2-7629-4525-b94e-994d0e1b4c02
# 0                                   True                                 False
# 1                                  False                                 False
# 2                                  False                                 False
# 3                                  False                                 False
# 4                                  False                                  True
# 5                                  False                                 False
# 6                                  False                                 False
# 7                                  False                                 False
# 8                                  False                                 False
# 9                                  False                                 False
# 10                                 False                                 False
# 11                                 False                                 False
# 12                                 False                                 False
# 13                                 False                                 False
# 14                                 False                                 False
# 15                                 False                                 False
# 16                                 False                                 False
#
# [17 rows x 155 columns]

# %%
# frequent_itemsets = fpgrowth(df, min_support=0.3, use_colnames=True)
frequent_itemsets = fpgrowth(df, min_support=0.0588, use_colnames=True)
### alternatively:
#frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
#frequent_itemsets = fpmax(df, min_support=0.6, use_colnames=True)

frequent_itemsets
# Out:
#         support                                           itemsets
# 0      0.058824             (fd70efc6-4bea-4488-9b48-259dedb17253)
# 1      0.058824             (f98db070-b1c2-4f1e-b019-c13361eeef96)
# 2      0.058824             (f278a7c1-0785-48d7-bf05-539b1f48cc0c)
# 3      0.058824             (c3f38f1d-a1be-477a-8692-9369ce7d2c44)
# 4      0.058824             (a32ff6ba-c480-4519-b91e-539517820571)
# ...         ...                                                ...
# 93914  0.058824  (3111288c-8e46-4664-8ab6-869604ec77f0, 2f17612...
# 93915  0.058824  (754519e3-1e83-4dbf-b7d4-4775fb960226, 2f17612...
# 93916  0.058824  (3111288c-8e46-4664-8ab6-869604ec77f0, 754519e...
# 93917  0.058824  (3111288c-8e46-4664-8ab6-869604ec77f0, 754519e...
# 93918  0.058824  (3111288c-8e46-4664-8ab6-869604ec77f0, 754519e...
#
# [93919 rows x 2 columns]

# %%
frequent_itemsets["length"] = frequent_itemsets["itemsets"].apply(lambda x: len(x))
### alternatively:
#frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
#frequent_itemsets = fpmax(df, min_support=0.6, use_colnames=True)

frequent_itemsets
# Out:
#         support                                           itemsets  length
# 0      0.090909             (fd70efc6-4bea-4488-9b48-259dedb17253)       1
# 1      0.090909             (f98db070-b1c2-4f1e-b019-c13361eeef96)       1
# 2      0.090909             (f278a7c1-0785-48d7-bf05-539b1f48cc0c)       1
# 3      0.090909             (c3f38f1d-a1be-477a-8692-9369ce7d2c44)       1
# 4      0.090909             (a32ff6ba-c480-4519-b91e-539517820571)       1
# ...         ...                                                ...     ...
# 72592  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, 699bfb4...       6
# 72593  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, 699bfb4...       6
# 72594  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, 699bfb4...       6
# 72595  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, e5bb3af...       6
# 72596  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, 699bfb4...       7
#
# [72597 rows x 3 columns]

# %%
large_frequent_itemsets = frequent_itemsets[frequent_itemsets["length"] >= 3]
large_frequent_itemsets
# Out:
#         support                                           itemsets  length
# 105    0.090909  (fd70efc6-4bea-4488-9b48-259dedb17253, f278a7c...       3
# 109    0.090909  (f278a7c1-0785-48d7-bf05-539b1f48cc0c, c3f38f1...       3
# 110    0.090909  (fd70efc6-4bea-4488-9b48-259dedb17253, f278a7c...       3
# 111    0.090909  (fd70efc6-4bea-4488-9b48-259dedb17253, c3f38f1...       3
# 112    0.090909  (fd70efc6-4bea-4488-9b48-259dedb17253, f278a7c...       4
# ...         ...                                                ...     ...
# 72592  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, 699bfb4...       6
# 72593  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, 699bfb4...       6
# 72594  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, 699bfb4...       6
# 72595  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, e5bb3af...       6
# 72596  0.090909  (d16e3a2f-05a7-40be-855e-5b810b524b61, 699bfb4...       7
#
# [72011 rows x 3 columns]

# %%
import psycopg2

conn = psycopg2.connect(database="web_honeypot_vps", user = "postgres", password = "admin", host = "127.0.0.1", port = "5432")

print("Opened database successfully")
# Out:
# Opened database successfully

# %%
# create table
cur = conn.cursor()
cur.execute('''CREATE TABLE assoc_rules_sess_uuids (
            ID INT PRIMARY KEY     NOT NULL,
            SUPPORT           REAL    NOT NULL,
            SESS_UUID            TEXT     NOT NULL);''')

print("Table created successfully")

conn.commit()
# Out:
# Table created successfully

# %%
# insert data

cur = conn.cursor()

insert_query = """
    INSERT INTO assoc_rules_sess_uuids (ID, SUPPORT, SESS_UUID)
    VALUES (%s, %s, %s)
"""

for idx, row in frequent_itemsets.iterrows():
    if idx == 1000:
        break
    cur.execute(
        insert_query,
        (int(idx), float(row["support"]), str(list(row["itemsets"])))
    )

conn.commit()
print("Records created successfully")
# Out:
# Records created successfully

# %%
# create table
cur = conn.cursor()
cur.execute('''CREATE TABLE assoc_rules_sess_uuids_large (
            ID INT PRIMARY KEY     NOT NULL,
            SUPPORT           REAL    NOT NULL,
            SESS_UUID            TEXT     NOT NULL);''')

print("Table created successfully")

conn.commit()
# Out:
# Table created successfully

# %%
# insert data

cur = conn.cursor()

insert_query = """
    INSERT INTO assoc_rules_sess_uuids_large (ID, SUPPORT, SESS_UUID)
    VALUES (%s, %s, %s)
"""

for idx, row in large_frequent_itemsets.iterrows():
    if idx == 1000:
        break
    cur.execute(
        insert_query,
        (int(idx), float(row["support"]), str(list(row["itemsets"])))
    )

conn.commit()
print("Records created successfully")
conn.close()
# Out:
# Records created successfully
